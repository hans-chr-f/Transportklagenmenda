# %%
# Prøver Playwright

# %%
import asyncio
from playwright.async_api import async_playwright, Page, TimeoutError
import os
import urllib.parse
import re
import nest_asyncio
nest_asyncio.apply()

# Limit the number of concurrent downloads
semaphore = asyncio.Semaphore(5)

def extract_case_number(onclick_attr):
    if onclick_attr:
        match = re.search(r"case=([^\']+)", onclick_attr)
        if match:
            return match.group(1)
    return None

async def download_pdf(button, page_number, index):
    async with semaphore:
        try:
            # Check if button is visible and enabled
            if not await button.is_visible():
                print(f"[WARN] Button {index+1} on page {page_number} is not visible. Skipping...")
                return

            if not await button.is_enabled():
                print(f"[WARN] Button {index+1} on page {page_number} is not enabled. Skipping...")
                return

            # Extract the 'case' value from the button's OnClick attribute
            onclick_attr = await button.get_attribute('OnClick')
            print(f"[DEBUG] Button {index+1} on page {page_number} OnClick attribute: {onclick_attr}")
            case_value = extract_case_number(onclick_attr)
            filename = f"{case_value}.pdf" if case_value else f"page{page_number}_index{index+1}.pdf"

            os.makedirs('pdfs', exist_ok=True)
            filepath = os.path.join('pdfs', filename)

            if os.path.exists(filepath):
                print(f"[DEBUG] File already exists: {filepath}, skipping download.")
                return

            # Attempt to click the button and handle the resulting popup
            print(f"[INFO] Clicking button {index+1} on page {page_number}")
            async with button.page.expect_event("popup", timeout=60000) as popup_info:
                await button.click()
            new_page = await popup_info.value

            # Wait for the download to start from the new page
            async with new_page.expect_download(timeout=60000) as download_info:
                pass
            download = await download_info.value
            await download.save_as(filepath)
            print(f"[INFO] Downloaded: {filepath}")

            await new_page.close()
        except TimeoutError as e:
            print(f"[ERROR] Timeout on page {page_number}, index {index+1}: {e}")
        except Exception as e:
            print(f"[ERROR] Error on page {page_number}, index {index+1}: {e}")

async def process_page(page: Page, page_number: int):
    print(f"[INFO] Processing page {page_number}...")
    try:
        buttons = page.locator('td.col_vis_saken > button')
        button_count = await buttons.count()
        print(f"[DEBUG] Found {button_count} buttons on page {page_number}")

        tasks = []
        for i in range(button_count):
            button = buttons.nth(i)

            # Log detailed button state
            print(f"[DEBUG] Button {i+1} on page {page_number} state:")
            print(f"  - Visible: {await button.is_visible()}")
            print(f"  - Enabled: {await button.is_enabled()}")
            print(f"  - Text: {await button.text_content()}")

            tasks.append(asyncio.create_task(download_pdf(button, page_number, i)))

        await asyncio.gather(*tasks, return_exceptions=True)
    except Exception as e:
        print(f"[ERROR] Error while processing page {page_number}: {e}")

async def main():
    async with async_playwright() as p:
        try:
            browser = await p.chromium.launch(
                headless=False,
                args=['--disable-blink-features=AutomationControlled', '--no-sandbox']
            )
            context = await browser.new_context(
                accept_downloads=True,
                java_script_enabled=True,
            )
            page = await context.new_page()
            await page.goto("https://reiselivsforum.no/web/dommer_og_avgjoerelser/")
            print("[INFO] Navigated to the main page.")

            page_number = 1
            target_start_page = 123

            while page_number < target_start_page:
                print(f"[DEBUG] Navigating to page {page_number + 1}...")
                next_buttons = page.locator('button:has-text("Neste side")')
                next_button_count = await next_buttons.count()
                if next_button_count > 0:
                    await next_buttons.first.click()
                    await page.wait_for_load_state('networkidle')
                    page_number += 1
                    print(f"[DEBUG] Reached page {page_number}")
                else:
                    print(f"[WARN] No more pages. Stopped at {page_number}.")
                    await browser.close()
                    return

            while True:
                print(f"[DEBUG] Starting to process page {page_number}")
                await process_page(page, page_number)

                next_buttons = page.locator('button:has-text("Neste side")')
                next_button_count = await next_buttons.count()
                if next_button_count > 0:
                    await next_buttons.first.click()
                    await page.wait_for_load_state('networkidle')
                    page_number += 1
                    print(f"[DEBUG] Moving to next page: {page_number}")
                else:
                    print("[INFO] No more pages to process.")
                    break

        except Exception as e:
            print(f"[FATAL] Error in main loop: {e}")
        finally:
            if 'browser' in locals() and not browser.is_closed():
                print("[INFO] Closing browser.")
                await browser.close()

# Run the asynchronous main function
asyncio.run(main())
# Out:
# [INFO] Navigated to the main page.
# [DEBUG] Navigating to page 2...
# [DEBUG] Reached page 2
# [DEBUG] Navigating to page 3...
# [DEBUG] Reached page 3
# [DEBUG] Navigating to page 4...
# [DEBUG] Reached page 4
# [DEBUG] Navigating to page 5...
# [DEBUG] Reached page 5
# [DEBUG] Navigating to page 6...
# [DEBUG] Reached page 6
# [DEBUG] Navigating to page 7...
# [DEBUG] Reached page 7
# [DEBUG] Navigating to page 8...
# [DEBUG] Reached page 8
# [DEBUG] Navigating to page 9...
# [DEBUG] Reached page 9
# [DEBUG] Navigating to page 10...
# [DEBUG] Reached page 10
# [DEBUG] Navigating to page 11...
# [DEBUG] Reached page 11
# [DEBUG] Navigating to page 12...
# [DEBUG] Reached page 12
# [DEBUG] Navigating to page 13...
# [DEBUG] Reached page 13
# [DEBUG] Navigating to page 14...
# [DEBUG] Reached page 14
# [DEBUG] Navigating to page 15...
# [DEBUG] Reached page 15
# [DEBUG] Navigating to page 16...
# [DEBUG] Reached page 16
# [DEBUG] Navigating to page 17...
# [DEBUG] Reached page 17
# [DEBUG] Navigating to page 18...
# [DEBUG] Reached page 18
# [DEBUG] Navigating to page 19...
# [DEBUG] Reached page 19
# [DEBUG] Navigating to page 20...
# [DEBUG] Reached page 20
# [DEBUG] Navigating to page 21...
# [DEBUG] Reached page 21
# [DEBUG] Navigating to page 22...
# [DEBUG] Reached page 22
# [DEBUG] Navigating to page 23...
# [DEBUG] Reached page 23
# [DEBUG] Navigating to page 24...
# [DEBUG] Reached page 24
# [DEBUG] Navigating to page 25...
# [DEBUG] Reached page 25
# [DEBUG] Navigating to page 26...
# [DEBUG] Reached page 26
# [DEBUG] Navigating to page 27...
# [DEBUG] Reached page 27
# [DEBUG] Navigating to page 28...
# [DEBUG] Reached page 28
# [DEBUG] Navigating to page 29...
# [DEBUG] Reached page 29
# [DEBUG] Navigating to page 30...
# [DEBUG] Reached page 30
# [DEBUG] Navigating to page 31...
# [DEBUG] Reached page 31
# [DEBUG] Navigating to page 32...
# [DEBUG] Reached page 32
# [DEBUG] Navigating to page 33...
# [DEBUG] Reached page 33
# [DEBUG] Navigating to page 34...
# [DEBUG] Reached page 34
Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [ERROR] Error on page 124, index 32: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [ERROR] Error on page 124, index 33: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [ERROR] Error on page 124, index 34: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [DEBUG] Button 36 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01600')
# [INFO] Clicking button 36 on page 124
# [DEBUG] Button 37 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01642')
# [INFO] Clicking button 37 on page 124
# [DEBUG] Button 38 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01647')
# [INFO] Clicking button 38 on page 124
# [DEBUG] Button 39 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01657')
# [INFO] Clicking button 39 on page 124
# [ERROR] Error on page 124, index 36: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [ERROR] Error on page 124, index 37: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [ERROR] Error on page 124, index 38: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [ERROR] Error on page 124, index 39: Target page, context or browser has been closed
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [DEBUG] Button 40 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01675')
# [INFO] Clicking button 40 on page 124
# [DEBUG] Button 41 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01695')
# [INFO] Clicking button 41 on page 124
# [DEBUG] Button 42 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01707')
# [INFO] Clicking button 42 on page 124
# [DEBUG] Button 43 on page 124 OnClick attribute: javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01725')
# [INFO] Clicking button 43 on page 124
# [ERROR] Error on page 124, index 40: Locator.click: Target page, context or browser has been closed
# Call log:
# waiting for locator("td.col_vis_saken > button").nth(39)
#   -   locator resolved to <button type="button" id="knapp_open_case40" onclick="javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01675')">Åpne sak</button>
#   - attempting click action
#   -   waiting for element to be visible, enabled and stable
#   -   element is visible, enabled and stable
#   -   scrolling into view if needed
#   -   done scrolling
#
# [ERROR] Error on page 124, index 41: Locator.click: Target page, context or browser has been closed
# Call log:
# waiting for locator("td.col_vis_saken > button").nth(40)
#   -   locator resolved to <button type="button" id="knapp_open_case41" onclick="javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01695')">Åpne sak</button>
#   - attempting click action
#   -   waiting for element to be visible, enabled and stable
#   -   element is visible, enabled and stable
#   -   scrolling into view if needed
#   -   done scrolling
#
# [ERROR] Error on page 124, index 42: Locator.click: Target page, context or browser has been closed
# Call log:
# waiting for locator("td.col_vis_saken > button").nth(41)
#   -   locator resolved to <button type="button" id="knapp_open_case42" onclick="javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01707')">Åpne sak</button>
#   - attempting click action
#   -   waiting for element to be visible, enabled and stable
#   -   element is visible, enabled and stable
#   -   scrolling into view if needed
#   -   done scrolling
#
# [ERROR] Error on page 124, index 43: Locator.click: Target page, context or browser has been closed
# Call log:
# waiting for locator("td.col_vis_saken > button").nth(42)
#   -   locator resolved to <button type="button" id="knapp_open_case43" onclick="javascript:window.open('/digiforms/sessionInitializer?processName=vedtak_PDF_Process&case=2018-01725')">Åpne sak</button>
#   - attempting click action
#   -   waiting for element to be visible, enabled and stable
#   -   element is visible, enabled and stable
#   -   scrolling into view if needed
#   -   done scrolling
#
# [ERROR] Error on page 124, index 44: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Error on page 124, index 45: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Error on page 124, index 46: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Error on page 124, index 47: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Error on page 124, index 48: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Error on page 124, index 49: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Error on page 124, index 50: Locator.is_visible: Target page, context or browser has been closed
# [ERROR] Timeout on page 124, index 35: Timeout 60000ms exceeded while waiting for event "download"
# =========================== logs ===========================
# waiting for event "download"
# ============================================================
# [FATAL] Error in main loop: Locator.count: Target page, context or browser has been closed
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 141
#     138                 await browser.close()
#     140 # Run the asynchronous main function
# --> 141 asyncio.run(main())
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# Cell In[17], line 136, in main()
#     134     print(f"[FATAL] Error in main loop: {e}")
#     135 finally:
# --> 136     if 'browser' in locals() and not browser.is_closed():
#     137         print("[INFO] Closing browser.")
#     138         await browser.close()
#
# AttributeError: 'Browser' object has no attribute 'is_closed'
