# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
import time
import requests
import os

# Configure Chrome options
chrome_options = Options()
chrome_options.add_argument('--headless')  # Run in headless mode
chrome_options.add_argument('--disable-gpu')
chrome_options.add_argument('--no-sandbox')

# Initialize the WebDriver
driver = webdriver.Chrome(options=chrome_options)  # Add executable_path if chromedriver is not in PATH

try:
    driver.get('https://reiselivsforum.no/web/dommer_og_avgjoerelser/')

    while True:
        # Wait for the page to load
        time.sleep(2)  # Adjust if necessary

        # Find all "Åpne sak" buttons
        buttons = driver.find_elements(By.XPATH, "//button[contains(@OnClick, 'window.open')]")

        for button in buttons:
            # Extract the 'case' parameter from the onclick attribute
            onclick_attr = button.get_attribute('OnClick')
            try:
                case_number = onclick_attr.split('case=')[1].split("')")[0]

                # Construct the PDF URL
                pdf_url = f"https://reiselivsforum.no/digiforms/vedtak_PDF?caseNumber={case_number}"

                # Check if the PDF has already been downloaded
                filename = f"{case_number}.pdf"
                if not os.path.exists(filename):
                    # Download the PDF
                    response = requests.get(pdf_url)
                    if response.status_code == 200:
                        with open(filename, 'wb') as f:
                            f.write(response.content)
                        print(f"Downloaded {filename}")
                    else:
                        print(f"Failed to download PDF for case {case_number}")
                else:
                    print(f"PDF {filename} already exists. Skipping download.")
            except Exception as e:
                print(f"Error processing button: {e}")
                continue

        # Check for the "Neste side >>" button to navigate to the next page
        try:
            next_button = driver.find_element(By.XPATH, "//button[contains(text(), 'Neste side')]")
            next_button.click()
        except NoSuchElementException:
            print("No more pages to load.")
            break
finally:
    driver.quit()
# Out:
# Failed to download PDF for case 2024-01648
# Failed to download PDF for case 2024-01089
# Failed to download PDF for case 2024-00410
# Failed to download PDF for case 2024-00698
# Failed to download PDF for case 2024-00956
# Failed to download PDF for case 2024-01367
# Failed to download PDF for case 2024-00803
# Failed to download PDF for case 2024-00718
# Failed to download PDF for case 2024-01070
# Failed to download PDF for case 2024-01344
# Failed to download PDF for case 2024-00676
# Failed to download PDF for case 2024-01345
# Failed to download PDF for case 2024-02107
# Failed to download PDF for case 2024-02136
# Failed to download PDF for case 2024-02354
# Failed to download PDF for case 2024-02423
# Failed to download PDF for case 2024-02430
# Failed to download PDF for case 2024-02470
# Failed to download PDF for case 2024-02607
# Failed to download PDF for case 2024-02609
# Failed to download PDF for case 2024-02307
# Failed to download PDF for case 2024-01781
# Failed to download PDF for case 2024-02101
# Failed to download PDF for case 2024-02164
# Failed to download PDF for case 2024-02320
# Failed to download PDF for case 2024-02444
# Failed to download PDF for case 2024-02457
# Failed to download PDF for case 2024-02474
# Failed to download PDF for case 2024-02525
# Failed to download PDF for case 2024-02538
# Failed to download PDF for case 2024-02555
# Failed to download PDF for case 2024-02589
# Failed to download PDF for case 2024-02597
# Failed to download PDF for case 2024-02855
# Failed to download PDF for case 2024-02299
# Failed to download PDF for case 2024-02154
# Failed to download PDF for case 2024-01921
# Failed to download PDF for case 2024-01953
# Failed to download PDF for case 2024-02076
# Failed to download PDF for case 2024-02188
# Failed to download PDF for case 2024-02545
# Failed to download PDF for case 2024-02440
# Failed to download PDF for case 2024-02286
# Failed to download PDF for case 2024-02212
# Failed to download PDF for case 2024-00694
# Failed to download PDF for case 2023-03936
# Failed to download PDF for case 2024-01998
# Failed to download PDF for case 2024-02093
# Failed to download PDF for case 2024-01877
# Failed to download PDF for case 2024-02443
# Failed to download PDF for case 2024-02746
# Failed to download PDF for case 2023-02543
# Failed to download PDF for case 2023-02854
# Failed to download PDF for case 2023-03314
# Failed to download PDF for case 2023-03707
# Failed to download PDF for case 2023-01350
# Failed to download PDF for case 2023-01476
# Failed to download PDF for case 2023-01557
# Failed to download PDF for case 2023-03421
# Failed to download PDF for case 2023-01223
# Failed to download PDF for case 2024-00287
# Failed to download PDF for case 2024-00310
# Failed to download PDF for case 2024-00553
# Failed to download PDF for case 2024-00592
# Failed to download PDF for case 2024-00634
# Failed to download PDF for case 2023-02723
# Failed to download PDF for case 2024-02040
# Failed to download PDF for case 2024-01894
# Failed to download PDF for case 2024-01872
# Failed to download PDF for case 2024-02182
# Failed to download PDF for case 2024-01812
# Failed to download PDF for case 2024-02537
# Failed to download PDF for case 2024-02534
# Failed to download PDF for case 2024-01890
# Failed to download PDF for case 2024-02291
# Failed to download PDF for case 2024-01529
# Failed to download PDF for case 2024-02260
# Failed to download PDF for case 2024-01686
# Failed to download PDF for case 2023-01281
# Failed to download PDF for case 2023-03857
# Failed to download PDF for case 2023-03952
# Failed to download PDF for case 2024-00284
# Failed to download PDF for case 2024-00512
# Failed to download PDF for case 2024-00027
# Failed to download PDF for case 2024-00305
# Failed to download PDF for case 2024-00509
# Failed to download PDF for case 2024-00630
# Failed to download PDF for case 2024-00361
# Failed to download PDF for case 2024-00082
# Failed to download PDF for case 2024-00582
# Failed to download PDF for case 2024-00223
# Failed to download PDF for case 2023-03595
# Failed to download PDF for case 2024-00658
# Failed to download PDF for case 2024-00652
# Failed to download PDF for case 2024-01069
# Failed to download PDF for case 2024-00650
# Failed to download PDF for case 2024-00456
# Failed to download PDF for case 2024-01791
# Failed to download PDF for case 2023-03237
# Failed to download PDF for case 2024-00348
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 57
#      55 try:
#      56     next_button = driver.find_element(By.XPATH, "//button[contains(text(), 'Neste side')]")
# ---> 57     next_button.click()
#      58 except NoSuchElementException:
#      59     print("No more pages to load.")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/webdriver.py:378, in WebDriver.execute(self, driver_command, params)
#     375     elif "sessionId" not in params:
#     376         params["sessionId"] = self.session_id
# --> 378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
#     380     self.error_handler.check_response(response)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:391, in RemoteConnection.execute(self, command, params)
#     389 trimmed = self._trim_large_entries(params)
#     390 LOGGER.debug("%s %s %s", command_info[0], url, str(trimmed))
# --> 391 return self._request(command_info[0], url, body=data)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/selenium/webdriver/remote/remote_connection.py:415, in RemoteConnection._request(self, method, url, body)
#     412     body = None
#     414 if self._client_config.keep_alive:
# --> 415     response = self._conn.request(method, url, body=body, headers=headers, timeout=self._client_config.timeout)
#     416     statuscode = response.status
#     417 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/_request_methods.py:144, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     136     return self.request_encode_url(
#     137         method,
#     138         url,
#    (...)
#     141         **urlopen_kw,
#     142     )
#     143 else:
# --> 144     return self.request_encode_body(
#     145         method, url, fields=fields, headers=headers, **urlopen_kw
#     146     )
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/_request_methods.py:279, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     275     extra_kw["headers"].setdefault("Content-Type", content_type)
#     277 extra_kw.update(urlopen_kw)
# --> 279 return self.urlopen(method, url, **extra_kw)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:793, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 response_conn = conn if not release_conn else None
#     792 # Make the request on the HTTPConnection object
# --> 793 response = self._make_request(
#     794     conn,
#     795     method,
#     796     url,
#     797     timeout=timeout_obj,
#     798     body=body,
#     799     headers=headers,
#     800     chunked=chunked,
#     801     retries=retries,
#     802     response_conn=response_conn,
#     803     preload_content=preload_content,
#     804     decode_content=decode_content,
#     805     **response_kw,
#     806 )
#     808 # Everything went great!
#     809 clean_exit = True
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/urllib3/connection.py:466, in HTTPConnection.getresponse(self)
#     463 from .response import HTTPResponse
#     465 # Get the response from http.client.HTTPConnection
# --> 466 httplib_response = super().getresponse()
#     468 try:
#     469     assert_header_parsing(httplib_response.msg)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# KeyboardInterrupt:
