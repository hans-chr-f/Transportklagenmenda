# %% [markdown]
# # Parsing av vedtakstekster (gammel)
#
# Vedtakene i tekstkorpuset må parses, dvs. vi må identifisere strukturen i vedtakene, og dele opp vedtakene i deres ulike deler. Formålet er å analysere korpuset, og å legge til rette for å en variert testing opp mot språkmodellen. Eksempelvis kan vi for eksempel teste ut søk der vi bare søker i klagers anførsler. Da kan vi etterpå bruke nemndas vurdering fra de samme vedtakene som kontekst opp mot språkmodellen. Et annet bruksområde er å identifisere og analysere vedtak der nemnda deler seg i et flertall og et mindretall. Da er det viktig å først identifisere hvilken del av vedtaket som er nemndas vurdering.
#
#
# ## Analyse av strukturen i vedtakstekstene
# Det ser ut til at mange vedtak har samme struktur: sammendrag, dato, saksnr. og tjenesteyter, så klagers anførsler, tjenesteyters anførsler og til slutt nemndas bemerkninger. Før vi går i gang med selve parsingen, skal vi analysere strukturen vedtakene. Hvilke overskrifter bruker vedtakene, har vedtakene de sammen overkriftene? Hvilke stabile strukturer vi kan basere oss på når vi skal parse teksten i vedtakene?
#
# Det er flere mulige tilnærminger til parsingen. Her bruker vi `pdfminer`, som er en modul i Python som leser font-informasjon i pdf-ene. Vi går da tilbake til pdf-ene for i første omgang å analysere hvilke overskrifter som er overskrifter i vedtakene. En gjennomgang av ulike vedtak gjør at vi kan anta at alle overskrifter i vedtakene er skrevet med uthevet font. Annen tekst bruker ikke uthevet font. Dette må selvfølgelig kvalitetssikres, men det virker som et godt utganspunkt for å identifisere overskrifter.
#
# Hvorfor ikke går rett på vedtakene og analysere tekstfilene vi allerede har etablert? Det er vanskelig å finne kjennetegn ved overskrifter i rent tekstformat som garanterer at vi identifiserer tekst som overskrift. Det er enkelt å hente ut tekst når vi vet hva overskriften er, og vi antar at dette er likt for alle vedtak. Men før vi kan anta at alle vedtak er like, må vi forsikre oss om at vi vet hva alle overskrifter er, og at alle vedtak har samme struktur.
#
# Strategien er altså å bruke `pdfminer`til lese ut tekst fra pdf-en. Vi leser ut tekst fra hvert enkelt vedtak, linje for linje. Hvis den første bokstaven i linjen er skrevet med fet font, lagrer vi tekstlinjen som en overskriftskandidat. Vi prøver først å analysere ett enkelt vedtak, her sak 2021-01885.

# %%
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTTextLine, LTChar

def extract_text_with_font(pdf_path):
    text_info = []

    for page_layout in extract_pages(pdf_path):
        for element in page_layout:
            if isinstance(element, LTTextContainer):
                for text_line in element:
                    if isinstance(text_line, LTTextLine):
                        # Forsøk å finne den første bokstaven i linjen
                        first_char = next((char for char in text_line if isinstance(char, LTChar)), None)
                        
                        if first_char is not None:
                            # Sjekk om den første bokstaven er uthevet
                            is_bold = "Bold" in first_char.fontname

                            # Hvis den første bokstaven er uthevet, betrakt hele linjen som uthevet
                            if is_bold:
                                text_info.append({
                                    "text": text_line.get_text(),  
                                    "font_name": first_char.fontname,
                                    "size": first_char.size,
                                    "is_bold": is_bold  
                                })

    return text_info

def main(pdf_path):
    teller = 0
    text_info = extract_text_with_font(pdf_path)

    print("\nIdentifiserte tekstlinjer med uthevet tekst:")
    print("--------------------------------------------")
    for info in text_info:
        print(info["text"].strip())  # Dette vil skrive ut hver uthevet linje som en separat streng
        teller +=1
    print("\nTotalt", teller, "overskrifter.")

if __name__ == "__main__":
    pdf_path = "./transportklagenemnda_pdfs/2021-01885.pdf"  # erstatt med stien til PDF-filen din
    pdf_path = "./transportklagenemnda_pdfs/
    main(pdf_path)
# Out:
# Identifiserte tekstlinjer med uthevet tekst:
# --------------------------------------------
# Vedtak i Transportklagenemnda - Fly
# Sammendrag
# Dato
# Saksnummer
# Tjenesteytere
# Klager har i det vesentlige anført
# Tjenesteyterne har i det vesentlige anført
# Nemnda bemerker
# Vedtak
# Nemndas representanter
#
# Totalt 10 overskrifter.

# %% [markdown]
# Koden finner det vi forventer. Den har identifisert alle overskrifter og utelatt annen tekst. Dette var for et enkelt vedtak. For å undersøke videre om denne metoden er robust, tester vi på alle vedtak. Det gir ikke mening å printe ut alle overskrifter for over 13 tusen vedtak. Vi leter derfor igjennom tekstlinjer med uthevet font og tar vare på alle unike tekstlinjer vi finner. Det skal da gi alle overskrifter som er brukt i vedtakene. Om metoden plukker med noe mer, vil vi også se det. (Koden under krever ressurser når antallet pdf-er er stort og tar derfor noe tid å kjøre)

# %%
import os
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTTextLine, LTChar

def extract_text_with_font(pdf_path):
    text_info = []

    for page_layout in extract_pages(pdf_path):
        for element in page_layout:
            if isinstance(element, LTTextContainer):
                for text_line in element:
                    if isinstance(text_line, LTTextLine):
                        # Forsøk å finne den første karakteren i linjen
                        first_char = next((char for char in text_line if isinstance(char, LTChar)), None)

                        if first_char is not None:
                            # Sjekk om den første karakteren er uthevet
                            is_bold = "Bold" in first_char.fontname

                            # Hvis den første karakteren er uthevet, betrakt hele linjen som uthevet
                            if is_bold:
                                text_info.append(text_line.get_text().strip())  # Hent hele linjeteksten

    return text_info

def main(directory_path):
    bold_lines_set = set()

    # Gå gjennom hver fil i katalogen
    for filename in os.listdir(directory_path):
        if filename.endswith('.pdf'):
            full_path = os.path.join(directory_path, filename)
            # Ekstraher de uthevede linjene fra den nåværende PDF-en og legg dem til i settet
            bold_lines = extract_text_with_font(full_path)
            for line in bold_lines:
                bold_lines_set.add(line)

    print("\nIdentifiserte linjer med uthevet tekst:")
    print("--------------------------------------------")
    for line in bold_lines_set:
        print(line)  # Dette vil skrive ut hver unike uthevede linje som en separat streng

    print("\nTotalt unike linjer med uthevet skrift funnet:", len(bold_lines_set))

if __name__ == "__main__":
    directory_path = './transportklagenemnda_pdfs/'
    main(directory_path)
# Out:
# Identifiserte linjer med uthevet tekst:
# --------------------------------------------
# har truﬀet alle rimelige tiltak for å unngå innstillingen. Klager har etter dette rett til
# oppdaget feilen på et tidligere tidspunkt.
# hun ble behandlet som en forbryter på ﬂyplassen og ble tvunget ned i en stol og ﬁkk
# innstillingen.
# Reisens pris: 31.240
# Tidspunkt: 121211 - 261211
# glasskår og maur overalt. Etter klage til hotellet ﬁkk de nytt rom.
# Turarrangør: TORP Booking
# Reisens pris: kr 12.536
# standard. Klager har derfor fått den standard han har betalt for. Sembo anser seg ikke
# Klager anfører at rommet manglet a/c som fungerte. På det meste var det 29 grader på
# vogn da han ble stanset. NSB har ikke gitt nærmere opplysninger om hvor lenge klager
# Flertallet kan ikke se at den forklaring Tripmonster gir, skal gi grunnlag for dette.
# Detur har i det vesentlige anført:
# Reisens pris: 20.000,-
# ﬂyvning fra Tromsø midtvinters. Etter mindretallets oppfatning er de-ices / av-ising
# Ticketgarantien således ikke anledning til å avbestille eller endre kun hjemreisen.
# for å få ordnet opp i manglene. Dag 2 ﬁkk de en ekstra seng på soverommet og da var
# Klager anfører at det ved innsjekkingen ca. kl 1500 oppsto problemer fordi resepsjonen
# eller svikt ved hotellet.
# Ving har anført at de aldri kan love tilstøtende rom, men overbringer ønske om det til
# Reisens pris: kr 16.066
# den ville ta 1 t. Hotellet hadde ingen resepsjon, men etter en tid ﬁkk de omsider nøkkel
# Nemndas mindretall, forbrukernes representanter, er av den oppfatning at et gebyr for
# er Oslo lufthavn Gardermoen - som ikke ligger i Oslo, og Moss lufthavn Rygge, som ikke
# benytter uttrykket tur/retur-reiser på sine hjemmesider til tross for at de i realiteten
# gjøres opp på stedet og således reduseres til kr 750. Jernbaneverkets representant
# klagers e-post av 15. april 2016. Dette stemmer også med det han ble fortalt av ansatte i
# Reisens pris: kr 18.005
# forsinket med nær en time grunnet sent innkommet ﬂy. Det fremkommer videre at
# tilby annet hotell forsøkte Ving å hjelpe til med det kunden ønsket.
# balkong og 2 senger som var 120 cm. Hotellet lå også usentralt.
# Brussel Airlines har i det vesentlige anført:
# Antall reisende: 11
# Turarrangør: Reisefeber.no
# det som et problem å gå med bagasje fra bussen til hotellet. De kunne på denne måten,
# Nemndas ﬂertall, samtlige medlemmer unntatt bransjerepresentant Amine
# Klager anfører at familien var forespeilet at Sea Side Studios var en fredelig og stille
# vesentlig at informasjonen gis på en betryggende måte, og at man er sikker på at
# i dagens ﬂymarked er vanlig med enkeltreiser. Det er videre vanlig at ﬂyselskaper
# at klager bestilte retur til 11. juli. Flertallet viser til at det gjaldt billetter til en ti-dagers
# ubehageligheter. Dette utgjør til sammen kr 910 + 811,- = 1.721,-
# RCCL
# Reisens pris: 7.835,-
# ikke gis noen refusjon, og at hele reisen da anses som avbestilt.
# Tjenesteyter følger ikke vedtaket i saken (07.06.2023)
# Bespisning. I henhold til program skulle de ha både lunsj og vinsmaking på slottet
# båten fra Trondheim sentrum med inntil 40 minutters samlet forsinkelse. Mindretallet
# Sideshore.no anfører at «kitecamp» er en aktivitetsferie der det tilbys overnatting, mat
# Majorstuen stasjon. Om bord var det billettkontroll og klager ble ilagt gebyr på kr 1150,-
# senere enn de skulle. Klager, som driver privat tannlegeklinikk, krever dekket tapte
# Reisens pris: kr 8.800
# til, noe som måtte endres like før katalogen ble trykt. På hjemmesidene er det derfor
# Klager har i det vesentlig anført:
# men de ville spandere på seg litt luksus og valgte familierommet på grunn av privat
# til at passasjerene ble forsinket i ﬂere timer. Norwegian plikter i et slikt tilfelle å tilby
# problemer som hun mener skyldtes mangel på planlegging og logistikk. Når det gjelder
# og mye fuktighet. Etter kontakt med Vings representant fungerte det i 1 ½ døgn, men
# den nektede ombordstigning gir klagerne rett til en erstatning på ytterligere 600 euro
# Mindretallet, ﬂyselskapenes representanter, er ikke enig i ﬂertallets vurdering. Ved
# foreslo en løsning enten med å henge opp et forheng eller leie en 1-roms leilighet i
# Edith Lundem Jakobsen, Lufthansa German Airlines
# gitt informasjon til arbeidsgiver og familiemedlemmer.
# Reisens pris: kr 69.281
# bagasje.
# Mare, var stengt pga mistanke om legionella. Det alternative hotellet, Jasmine Villige,
# julebordet skulle være gratis. Det ble sagt på telefon at 2 måltider var gratis, og det
# Lyon. Før klager bekreftet bestillingen kom det opp et vindu med reiseruten. Her
# Tyrkiareiser viser til beskrivelsen i katalog og på nettsider der det fremgår at hotellet
# om hvor lenge klager oppholdt seg i ubetjent vogn før kontrollen ble foretatt, hvor
# forordningen ikke kommer til anvendelse i saken. Flertallet viser til forordningens
# Reisens pris: 16.340,-
# Lastebiler og sementblandere stengte ofte veien slik at det var vanskelig å komme
# Ving har vist til at informasjon om byggearbeid er gitt både på reisedokumentene og
# Nemnda har ved den videre vurderingen av saken delt seg i et ﬂertall og et mindretall.
# Reisens pris: kr 55.374
# argumentasjon i saken forvirrende.
# hundre meter ut og full av søppel.. De avventet først høyvannet for å se om det ble
# Klager an fører at de måtte gå opp 94 trappetrinn med barnevogn, koﬀerter og
# rettighet mht. avbestilling mv. som om reisen var bestilt direkte fra ﬂyselskapet. Etter
# Reisens pris: kr 48.549
# samt pris og ekstra sesongavgifter. Det er ikke korrekt at klager først ble informert
# Forbrukerrådet, legger til grunn at hotellets egen beskrivelse, samt andre omtaler
# fra 21 til 29 februar 2015», og heller ikke at klager i mail 20. juni 2014 begrunner sitt
# forhånd fordi han syntes endringen ble svært dyr. Flertallet viser til at Norwegian ikke
# Klager anfører at hun og de hun reiste sammen med, måtte forlate bussen på vei til
# tilfellet har gitt tilfredsstillende informasjon om endringer gjennom melding til oppgitt
# Reisens pris: kr. Ca. 9,000,-
# også at klagers problemer kunne vært redusert dersom klager hadde forholdt seg
# ble sendt fra Oslo med en ny del.
# Klager anfører at hotellet ikke samsvarte med beskrivelsen av et 5* hotell.
# montert i lav høyde. Det var derfor umulig å sitte på altanen fordi varmluft kom ut av
# deltagerne formidlet at mye skulle klaﬀe for at ekspedisjonen skulle nå polpunktet
# Ving har anført at renhold der er vesentlig enklere enn hjemme.
# Reisens pris: kr.17.780
# egenhånd.
# Tidspunkt: 020711 - 240712
# samlet refusjon på kr.2.500,-.
# omstendighet i forordningens forstand. Mindretallet viser til at en uventet hendelse
# representanter er i tillegg av den oppfatning at et eventuelt gebyr fra reisebyråets
# Tidsrom: 171113 - 241113
# I dette tilfelle må det legges til grunn at forsinkelsen skyldtes værforholdene og de
# Klageren anfører at de ved ankomst ﬁkk et rom som var skittent, gammelt og slitt,
# Flertallet er av den oppfatning at plasseringen av skiltene og teksten på skiltene burde
# Klager anfører at avreise ble ca. 7 t forsinket og ankomst Palma 7 t og 20 min etter
# Etter mindretallets syn kan det synes som om det ikke ble klaget til turoperatørens
# Turarrangør: Solfaktor Pluss AS
# hadde Apollos buss til hotellet forlatt ﬂyplassen da de kom ut av terminalen. De måtte
# støy fra nabolaget, bad og WC var trangt, tett sluk og dårlig vanntrykk, manglende
# klagerne ﬁkk en mangelfull reise. Det fremgår av Vings informasjon om hotell
# fra Phuket til Bangkok uten at det ﬁkk innvirkning på resten av reisen til Trondheim.
# Reisens pris: 17.250
# Nemndas representanter
# Nemnda har ved vurderingen av dette spørsmålet delt seg i et ﬂertall og et mindretall.
# Hit Travel har ikke avgitt uttalelse til Reklamasjonsnemnda, men har i sitt svar til
# av hvilken informasjon og anvisninger de ﬁkk av en navngitt representant fra Røros
# mener at SAS sin beslutning i denne saken om å omdisponere ﬂyindividene ikke er
# Klager anfører at bussreisen fra ﬂyplassen til hotellet tok 3 t - noe de ikke hadde fått
# en billett. Mindretallet mener derfor at gebyret bør frafalles av rimelighetsgrunner.
# første at selskapet kun kan kreve et slikt gebyr dersom dette fremkommer klart
# RCCL har ikke avgitt uttalelse til nemnda. Til klager har RCCL i det vesentlige anført:
# Via Tours/MSC Cruises har i det vesentlige anført:
# politianmeldt av hotellets ledelse. Ving har stor forståelse for at det tar tid å bearbeide
# hotellet. De fant seg da et annet hotell på egen hånd og krever refundert merprisen på
# Kenba Travel har i det vesentlige anført:
# Klager anfører at hun bestilte plass på Hotell Folias, som hun kjente fra før og ønsket
# Nemndas mindretall, forbrukernes representanter, mener at det i tillegg er grunnlag
# Klager anfører at hotellet de bodde på, hadde meget lav standard.
# Klageren anfører at han ved bestillingen av reisen var klar og tydelig på at stranden
# selv med en liten forsinkelse på ﬂyvningen. Flyselskapene har større mulighet enn
# Erstatningen dekker så vel økonomisk som ikke økonomisk tap.
# Star Tour anfører at ingen hoteller har samme antall solsenger som gjester.
# informasjon på annen måte.
# ﬂertallet.
# klagerne har lidt et økonomisk tap i form av en tapt, forhåndsbetalt feriedag.
# Brev om dette og ny bekreftelse som inneholdt nye rutetider ble sendt 14. mai. Den
# å kansellere ﬂyvningen til Alghero da den kunne ha blitt ﬂøyet fra Gardermoen.
# med ﬂyet som skulle ha operert DY623, og det var således ikke nødvendig å innstille
# Klager anfører at hans kvinnelige reisefølge (A) ble tvunget til å forlate skipet mens
# neste dag.
# eller mangler ved reisegodset.
# lederen og forbrukernes representanter er av den oppfatning at man ved en ved
# Tjenesteyter følger ikke vedtaket i saken (21.08.2017)
# og forståelig beskjed om hva som gjaldt.
# Turarrangør: Fotball Norge
# om dette i en mail de sender ut en uke før avreise. Når klager tross dette ved sin
# Via Egencia har i det vesentlige anført:
# Flertallet, samtlige medlemmer med unntak av Amine Hansen, ﬁnner på bakgrunn av
# Nemndas mindretall, forbrukerrepresentantene, legger klagers versjon om at det ble
# treningsrom. Det viste seg å være et slitt rom med omtrent ingenting av utstyr.
# eller på Vings nettsider. Hotell Servatur Casablanca har følgende omtale: Turistområde
# Klager anfører innledningsvis at de opplevde språkproblemer på hotellet fordi ingen
# reisemål. Det er orientert om dette på Vings nettsider. På dette hotellet var anlegget
# Reisens pris: Kr. 45.708
# Klager har opplyst at hun forut for turen tok kontakt med hotellsjefen på skipet for å få
# Ving har anført at klageren tok kontakt med Ving 2 dager etter ankomst.
# kan derfor ikke henvise deltagerne til ﬂyselskapet, jf. pakkereiseloven § 6-5 annet ledd
# Detur Her ble det en svikt i systemet slik at Solfaktors betaling til Detur ikke nådde
# bestillingen. Straks etter bestillingen ﬁkk klager en bekreftelse til den oppgitte e-post
# dette av en analogisk fortolkning av artikkel 7 nr 1 siste ledd.
# for å tilkjenne klager kompensasjon for ikke - økonomisk tap, jf. pakkereiselovens § 6-4.
# Star Tour har anført at hvis det er noe en gjest er misfornøyd med,å det tas kontakt
# programmet en 5* hytte. Det viste seg at hytta hadde et tak som var lekk, og vannet
# En del ﬂyselskap kansellerer automatisk returreisen dersom utreisen ikke benyttes.
# hadde ikke samme standard og beliggenhet, og rommet var nedslitt, trangt og mørkt.
# misforståelsen som er oppstått og ﬁnner ikke å kunne anbefale at klager gis medhold.
# var følgene av en ekstraordinær teknisk feil på ﬂyet KKF.
# henne. Utﬂukten til Milano ble kansellert og de kom heller ikke til «Verona by night».
# var forsinket ut fra Oslo, og det er ingen dokumentasjon av påberopte værforhold.
# at dette er rom for dem som ikke stiller spesielle krav til beliggenhet og utsikt.
# omstendigheter ikke kan anvendes. I dette tilfelle er det etter mindretallets oppfatning
# Klager opplyser at ved ankomst ﬂyplassen satt han lengt bak i bussen med den 1 år
# Hit Travel anfører at det som var inkludert i grunnpakken, var hotell med frokost.
# som kan avklare spørsmålet. Det må etter ﬂertallets vurdering gå ut over Norwegian
# Lowcostholidays har i det vesentlige anført:
# kunden nei til. Personalet på hotellet tilbød et nytt rom, men viste ved en feil kunden
# hele kroppen. Klager er selv lege og vet at dette ikke var sandﬂuebitt. De krevde å få
# på at to personer deler rom.
# Klager føler seg derfor lurt og krever tilbakebetalt diﬀeransen mellom kr.1.770,- og
# utsikten ikke samsvarer med beskrivelsen. Det er også uheldig at nærheten til
# mindretallets vurdering bør klager få erstatning tilsvarende utgifert til ﬂytoget.
# Situasjonen var kaotisk, og det var ikke realistiske muligheter til å komme i kontakt
# «tatt plass» i vognen da han ble ilagt kontrollgebyr. Klager hevder at kontrollen fant
# Destinasjon: Tunisia
# Mindretallet ser det slik at det er klager som har forårsaket risiko og påfølgende tap, og
# derfor at den konkrete klage må bli å avvise, jf. transportklagenemndforskriften § 6-2.
# teppegulv slik at hotellet hadde hatt mulighet til å plassere dem i annet rom - Da guide
# utilpass. Byggestøyen gikk langt ut over det som var antydet i informasjonen fra Ving,
# så som den i hovedsaken omhandlede, som har oppstått plutselig, som ikke kan
# denne plikten er overholdt. Flertallet ﬁnner derfor at saken bør behandles etter EU-
# Reisens pris: kr.28 074
# de tre som skulle reise og det ble avtalt at fru X skulle ringe dagen etter med nærmere
# Turarrangør: expedia.no
# maur, kakerlakker og mygg. Sier man fra i resepsjonen blir rommene sprayet og det er
# gebyr for manglende billett. Klager får dekket månedskort av NAV og hadde kjøpt
# kommet, hadde Star Tour fått vite om overbookingen før avreise fra Norge.
# fast i dom av ECJ Grand Chamber i «IATA». Artikkel 6 i forordningen gir klare og presise
# rommet etter skifte av sengetøy og håndklær.
# Star Tour har anført at de har tatt forbehold om endringer i hotellprogrammet på sine
# for å overprøve kapteinens beslutning om å returnere til Stavanger, Det oppstod et
# Tjenesteyter følger ikke vedtaket i saken (27.06.2023)
# Forsinkelsen gir således rett til en standarderstatning på 400 euro per passasjer.
# Reisens pris: kr 23.216
# kan ha vært den beste helhetsløsning, kunne den ha blitt unngått. Flertallet er av
# Kunden kreve at arrangøren avhjelper mangelen dersom dette kan skje uten urimelig
# Reisens pris: kr.28.840
# er fremstilt i denne saken ville klagerne heller ikke ha oppdaget feilen om de hadde
# Klager anfører at de opprinnelig ikke hadde bestilt all inklusive, men at de ønsket
# informert om dette. Den stedlige representanten valgte i stedet å oppgradere til et 5*
# Nemndas mindretall, de to bransjerepresentantene fra reiselivet, er av den oppfatning
# renhold og hygiene.
# opplysninger til grunn at denne kanselleringen var begrunnet i operasjonelle hensyn og
# innreisedokumenter i orden.
# former for teknisk svikt fritar selskapet for ansvar. Luftfartsloven har ikke samme
# Tidsrom: 030213 - 170213
# at klager hadde «tatt plass» i vognen da hun ble ilagt kontrollgebyr. Flertallet viser
# kakerlakker. Etter kontakt med Ving ﬁkk de bytte til annet hotell mot å betale 175 euro.
# passasjer. Finnair har anført at retten til erstatning ikke omfatter klagernes barn under
# Mindretallet, bransjerepresentant Monica Grimstad, er av den oppfatning at Norwegian
# Han reiste derfor hjem etter et par dager.
# vurdering videre den konsekvens at Lufthansa overfor klager er å anse som «det
# Klager anfører at de var en del par som skulle reise sammen til Gran Canaria.
# nødvendig å forsinke denne ﬂygningen. Det forelå ingen ekstraordinær omstendighet
# opp passasjerer med innsjekket bagasje som ikke møter opp ved gaten.
# gratis shuttlebuss til sentrum, noe det var på Pastana Grand.
# hotellet. Det viste seg imidlertid at stranden var konstant tørrlagt. Det gikk en bro 80
# håndtert bedre. I den utstrekning klagerne ble påført utgifter til mat mv. anbefaler
# Club Royal har gitt uttrykk for at de har oppdaget mange feil og mangler ved sine reiser
# Tjenesteyter følger ikke vedtaket i saken (29.10.2024)
# Reisens pris: kr 16.546
# Klager anfører at de hadde bestilt et hotell, Hilton Long Beach, som var klassiﬁsert som
# Reisens pris: 17.481,-
# Turarrangør: Scandorama
# av utgiftene anslås disse skjønnsmessig til 1&nbsp;750 kroner. Flertallet anbefaler at
# Reisens pris: kr 13.653
# bord. Det er også bekreftet at det var problemer med toalettet på et tidspunkt, men
# det synes inkonsekvent når mindretallet på den ene side legger til grunn at Alminnelige
# Tidsrom: 290113 - 050213
# forsinkelser. Selv om dom ved forsinkelser foreligger, er dommen utfordret bl.a.
# Reisens pris: 9.610,-
# Apollo har erkjent at det var mangler ved Hotell Heaven og har refundert kr.1.000,- som
# avvises, jf. transportklagenemndforskriften § 6-2 bokstav d.
# for.
# til anvendelse. § 33 lyder:
# slik at man måtte ut på platting eller gjennom vanlig inngangsdør.
# som er et EU-selskap, det er utstedt en e-billett på samme EU-selskap og de enkelte
# Klager anfører at hennes ryggsekk ble borte på veien fra leiligheten på Gran Canaria til
# kan anses som allment kjent at man ikke har anledning til å benytte en returbillett
# Turarrangør: Australiareiser AS
# Den forsinkede bagasje førte til utgifter og ulemper for klagerne. Finnair har erkjent
# soverom og to bad. De hadde året før hatt slik innkvartering på dette hotellet.
# Klager anfører at det ikke burde stå i hotellbeskrivelsen at hotellet er nyoppusset fra
# person). Turen skulle gå 17. juni. Innbetalingen skjedde 2. mars, og kort etter avbestilte
# ruteendringen førte til at klager ikke ﬁkk benyttet forhåndsbestilt hotell i Praha, og at
# Nemndas mindretall, forbrukernes representanter, ﬁnner etter en samlet vurdering
# per person. Flertallet viser til at det følger av EU forordning 261/2004 artikkel 4 nr 3 at
# TicketSki har i det vesentlige anført:
# Vedtak blir etter dette fattet i tråd med ﬂertallets syn.
# bestilling, ikke bare i form av opplysninger i turkatalog eller lignende. I denne saken er
# vanskelige værforhold, og at kanselleringen ikke kunne vært unngått selv om alle
# mange ﬂyselskap. Klager ﬁkk tilbud om å reise på sammenliknbare reisevilkår fra Oslo
# arbeidere som sto utenfor på terrassen og malte. Han ba om rombytte og ﬁkk det etter
# skaden da hun kom hjem, og til at klager møtte frem den påfølgende dag for å skrive
# erstatningens størrelse, bemerker ﬂertallet at erstatningen ved totalskade i
# svart klager følgende.
# Klager anfører at to av reisefølgets koﬀerter ikke kom på bagasjebåndet da de ankom
# Star Tour / Thomson Airways har i det vesentlige anført:
# problem med en oljepumpe fritar ikke turarrangør/ﬂyselskap for ansvaret.
# De ble henvist til hotell Riad Andalouse.
# 300. Mindretallet, ﬂyselskapenes representanter, mener at det ikke er grunnlag for
# å holde kostnaden nede. Reiselivsreprensentantene anbefaler derfor, etter en
# Tidspunkt: 171111 - 011211
# erstatningen settes til 3 000 kroner.
# foreligger følgelig ikke grunnlag for kompensasjon.
# at passasjerene ikke har rett til både standarderstatning for kansellering og
# vurdering ikke godtgjort at Travellink gjorde det man kunne forvente av en profesjonell
# dagen ødelagt. Blue Dom holdt heller ikke mål sammenlignet med det som var bestilt -
# 24.februar med ankomst Oslo kl.1200. Tidspunktene ble senere endret slik at ankomst
# helt klart må bebreides for ikke å ha skrevet ut og sjekket datoene på billettene, og
# Club Royal har opplyst at på grunn av endrede ﬂytider ble det en lunsj og en middag
# eller vår Facebook side for detaljerte busstider''. I noen tilfeller kan man oppleve
# Klagerne opplyser at de deltok på en «juletur» til Spania i perioden 23. desember til 2.
# seg om at avstand til strand var riktig. Hun tok både kontakt per telefoner og e-post til
# Reisemål: Spania, Albir
# Nemndas Flertall legger etter dette til grunn at bestillingen ble foretatt med kjennskap
# kundeservice, hvor hun ble informert om at opplysninger som angitt var riktige.
# Solia har anført at de på grunn av stor etterspørsel måtte ta inn et ekstrahotell, og på
# kan stilling til.
# Klager anfører at de måtte vente hele 45 min før bussen gikk fra ﬂyplassen til hotellet.
# Reisens pris: kr 21.630
# Nemndas mindretall, ﬂyselskapenes representanter, ﬁnner ikke grunnlag for
# records er ikke vedlagt. Nemndas ﬂertall, lederen og forbrukernes representanter,
# Reisens pris: nok. 48.000
# Flertallet, lederen og forbrukernes representanter, er av den oppfatning at Norwegian
# var nedslitt og overbooket, noe som førte til en rekke problemer bl a ved bassenget og
# Jet2.com har ikke avgitt uttalelse til nemnda. Til klager har selskapet i det vesentlige
# Klager har i det vesentlige anført:  9. august 2009 kl 20.20 skulle BGS guide returnere
# Kanselleringen gir følgelig rett til en standarderstatning på 250 euro. Nemnda anbefaler
# Tidspunkt: 140811 - 280812
# 3 personer i dobbeltsengen. Det var bare et stort håndkle til hver av rommene, og de
# Danish Air Transport har i det vesentlige anført:
# det var planlagt ﬁske i, Clear Creek, var helt stengt for ﬁske etter kongelaks, men at de
# drikke og av badevannet. Det anføres at påstanden om oppvask bare under rennende
# MSC Criuses side i det de sendte epost om oppgradering og hva dette innebar. Dette
# overfor reisebyråer. At «Supersaver følger ﬂyselskapenes regler for bestillinger» må
# confronted as a matter of course with unexpected technical problems. Furthermore,
# Reisens pris: 14.068 innkl. ﬂy
# bilder. Ved bestillingen ble både hotell og pris akseptert.
# Flertallet ﬁnner videre godtgjort at kanselleringen ikke kunne vært unngått selv om
# det etter en helhetsvurdering synes rimelig.
# lastes for. Det var også god informasjon i media om streiken. Norwegian har ingen
# avgang fra Oslo S henvendte seg til togpersonalet for å kjøpe billett og at kontrollen
# TyrkiareiserAS har i det vesentlige anført:
# Antall reisende: 4 voksne og 2 barn
# og ballkong. Hotellet lå midt i innﬂytningen til ﬂyplassen med mye støy.
# Mindretallet er derfor av den oppfatning at ﬂyselskapet ikke har tilbudt den assistanse
# Reisens pris: 6.082,-
# ble gjort. Klager forsøkte deretter forgjeves å ringe det Apollo-nummer han hadde fått
# Ving har vist til reiseinformasjonen hvor det opplyses om at hoteller ofte har sentral
# Flyservice. Nemnda ba i e-post av 26. februar 2013 Norwegian om å forelegge klagers
# Klager opplyser at de hadde bestilt tur til Maldivene og skulle bo 7 dager i bungalow på
# mindretall, ﬂyselskapenes representanter, mener at det ikke er grunnlag for å tilkjenne
# av samme årsaker som tilfellet var i Bodø. Noe annet vil være å straﬀe ﬂyselskapene
# med markbalkong - er vanskelig å forene med den informasjon som fremgår av Star
# Klager anfører at de ikke har fått det de har bestilt og betalt for.
# Klageren var sammen med sin mann på en tur til Tyrkia med Oska Travel.
# at selskapet også ville arrangere omruting for klager.
# Reisens pris: 9.690,-
# for å sjekke at bestillingen er korrekt. KLM kan ikke lastes for at klager ikke sjekket
# Small Planet Airlines har ikke avgitt uttalelse til nemnda eller til klager.
# kravet.
# Klagerne anfører at rommene ikke var klare da de ankom. De måtte sette bagasjen
# Klager anfører at hotellet lå i «et avsidesliggende slumstrøk» hvor det var ubehagelig å
# uerfaren og ble altså byttet ut. Situasjonen er da at første klage kom på dag 2 om
# Nemndas mindretall, Linda Olsen, bemerker:
# Reisens pris: kr 22.892
# omstendighet, og at Norwegian derfor ikke hefter for en standardisert kompensasjon.
# kl.04.30 med ankomst Sola kl.08.00. I hjemreiseinformasjonen som ble lagt ut på
# Detur og de har fått ﬂere negative tilbakemeldinger og har stoppet videre salg av det.
# Reisens pris: 11.430,-
# New York. Flertallet er av den oppfatning at dette er å anse som en ekstraordinær
# Turarrangør: Merlot Reiser AS
# Chamber i «IATA». Artikkel 6 i forordningen gir klare og presise anvisninger på
# Mindretallet, bransjerepresentant Olav Grøttland, har et annet syn på saken.
# en erstatning på kr 7.499. For så vidt angår beløpets størrelse, bemerker ﬂertallet at
# Mantareiser har i det vesentlige anført:
# foreliggende opplysninger ikke sannsynliggjort at innkjøpet fra Mode Szenario var et
# vært behjelpelig med hotellbytte til hotell med a/c.
# Reisens pris: 59.580
# En samlet nemnd legger til grunn at Norwegian ikke kunne tilby omruting med ﬂy
# at en representant fra Thai Airways ga uttrykk for at klager kunne droppe ﬂygningen
# Opodo/Travellink har ikke gitt uttalelse til Flyklagenemnda. Til klager har selskapet i
# Star Tour anfører at forsinkelsen på utreisen og hjemreisen ikke var av en slik varighet
# opptrådt korrekt og at gebyret størrelse således skal være kr 900.
# Traﬁkkstøyen var også alvorlig og det var livsfarlig for en 10-åring å krysse veien alene.
# Reisens pris: 22.600 nok.
# å få trene på et velutrustet treningsanlegg som ligger i tilknytning til hotellet.
# skulle arrangere med lokal buss eller båt, men reiseleder har i ettertid opplyst at dette
# en åpen bue inn. Ving har hatt dette bostedet i sitt program i ﬂere år, og fordi de ikke
# GoSyden har i det vesentlige anført:
# US Airways har i det vesentlige anført:
# hverandre og med dør imellom. Det betød toppleiligheter på Villa Ankora.
# forbrukernes representanter, at klager gis en kompensasjon på NOK 300. Mindretallet,
# med Lufthansa.
# Flytogets busser.
# kunden ikke tatt dette opp på stedet.
# Ving har vist til logen fra reisemålet. Der fremgår det at Vings representant besiktiget
# hollandske gjestene ﬁkk en advarsel og ble senere bortvist.
# oppholdt seg i ubetjent vogn før kontrollen ble foretatt, hvor kontrollen ble foretatt
# ville begrense passasjerens tap ved at han rakk sin videreforbindelse fra Torp. Tiltaket
# Takvam-Borge, er av den oppfatning at en teknisk svikt likevel kan komme så uventet
# skaden og påfølgende innstilling ikke gir rett til standarderstatning. Operatører av
# kan sannsynliggjøre utgiftene på annen måte, anbefaler nemndas ﬂertall, lederen
# og i skriv lagt på rommene. De ga derfor tilstrekkelig informasjon så snart det var
# Destinasjon: Tyrkia, Incekum
# I tillegg kommer endringsgebyrene NOK 1500
# Nemndas ﬂertall kan etter dette ikke se at språkreisen led av en mangel som kan føre
# Detur har til nemnda anført:
# under headingen «Hvis bagasjen ikke kommer» i forbindelse med «Praktiske tips»:
# at mail ikke kommer frem til mottaker og da mener mindretallet at klager selv
# Nemnda ﬂertall, formannen og ﬂyselskapenes representanter, er av den oppfatning at
# fremkommer videre av vilkårene at billetten regnes som avbestilt dersom utreisen
# anbefale at Norwegian bør dekke klagers utgifter til hotell m.v. Flertallet viser videre
# crew meldte seg syke denne dagen.
# av hotellet, beskriver at hotellet er spesielt rettet inn mot homoﬁle, men at det også
# mindretallets vurdering er en lovlig, varslet streik en generell risiko ved å drive en
# et moderne og nydelig beliggende strandhotell rett utenfor byen.
# Reisens pris: kr 67.000,-
# billetten som allerede er refundert.
# med fradrag av kr.1.000,- per familie. Klager har også gjort endringer etter bekreftelsen
# med Vings representant på stedet til tross for at klager var i kontakt med guiden en
# grunnlag for å laste Norwegian for at klagerne ikke ﬁkk sjekket inn i tide. Norwegian
# sannsynlig at klagerne ikke møtte frem til innsjekkingen i tide. Om klagerne hadde
# klassiﬁsering. De antar at klagers misnøye beror på den oﬃsielle klassiﬁseringen.
# klager. På nettsidene fremgår beskrivelsen av hva ekstraseng kan være.
# plass videre til Finland før etter ytterligere en dags venting slik at de kom hjem 2 dager
# Klager anfører at hun ikke ﬁnner det sikkert å booke dyre reiser på internett.
# og ﬂyplassavgifter fra ﬂyselskapet. Videre vil mindretallet påpeke at det anses som
# tilbød ombooking på første mulighet, i dette tilfellet tidlig morgenen etter, som
# Ryanair har ikke avgitt uttalelse til klager eller til nemnda.
# Reisens pris: 13.571,-
# utbetaler en kompensasjon på 2&nbsp;000 kroner for den ulempen klagerne ble påført.
# Hun ble, sammen med sitt reisefølge, plassert i en taxi og kjørt til et annet hotell som
# anbefaler ﬂertallet i nemnda, lederen og forbrukernes representanter, at klagerne gis
# om endringen. Det må etter mindretallets vurdering være klagers ansvar at mailene
# Reisens pris: kr.11 700
# lengre tidsintervaller mellom ﬂyvninger som kan gi tid til utbedring av feil uten å
# at det gir grunnlag for kompensasjon.
# var fullt. Hun måtte derfor ha barnet på fanget i 4 t. Hun krever refundert det som er
# Klager anfører at nettsidene viste bilde av et basseng med vannsklier, og det var
# Destinasjon: Tenerife
# etter denne dato og det er heller ikke lastet ned noen periodebillett. Mindretallet
# reisens avslutning med mindre særlige grunner foreligger. Det foreligger her ingen
# som en stor aktør, ta saken opp med hotellet med sikte på at ikke andre gjester blir
# ukjent og som ikke samsvarer med noen andre artikler i forordningen.
# som ikke var betjent. «Hotline»-nummeret stod på billetten. Mindretallet er av den
# i 1973 og at bare noen rom er renovert. Klager måtte derfor være forberedt på at de
# stedet feilaktig å avvise klagen på formelt grunnlag.
# Reisens pris: 17.300,-
# datasystem.
# bestemt - 2. oktober kl 23.15 i stedet for kl 20.45. På avreisedagen ﬁkk hun ny SMS om
# til standarderstatning på 250 euro i henhold til EU forordningen.
# Tjenesteyter følger ikke vedtaket i saken (09.11.2022)
# gjenstand har medført. Det er etter ﬂertallets vurdering ikke sannsynliggjort at det er
# Nemndas mindretall, Vings representant,kan ikke si seg enig med ﬂertallet i at
# for returreisen og enveisbillett på strekningen målt opp mot prisene ved bestilling av
# av 6. mai 2010, Walz-Clickair. Flertallet anbefaler at Widerøe utbetaler en kompensasjon
# annet enn mindre riper i håndbagasjen, og det synes etter ﬂertallets vurdering usikkert
# og klager har fått suite i henhold til bestillingen. Han har heller ikke bedt om å få
# som har var tvunget til å betale for å få utlevert bilen.
# andre ﬂyselskaper. Finnairs rute videre til Finland hadde kapasitetsmangel og klager
# Amisol har i det vesentlige anført:
# Condor har i det vesentlige anført:
# frem til det endelige bestemmelsesstedet innen det planlagte ankomsttidspunktet.
# Klager anfører at da de 30. januar 2011 bestilte rom, vurderte de ut fra informasjonen
# man ikke det, har man ikke krav på kompensasjon i ettertid.
# Mindretallet, forbrukernes representanter, er av den oppfatning at Travellink ikke er
# pakken. Da var utﬂukts pakken med lunsj for kr.275,- inkludert.
# hele klagernes tap.
# Detur Norway har i det vesentlige anført:
# Klager anfører at de ble tildelt rom i et gammelt leilighetskompleks på andre siden av
# Ruters billettsystem.
# Klagerne bestilte pakketur gjennom Ticket med utreise fra Oslo 12. oktober 2013.
# endringen på e-post/sms. SAS burde i tillegg ha forsikret seg om at informasjonen var
# Continental Airlines har ikke avgitt uttalelse til nemnda. Til klager har Continental
# den 25. mai. Endringen førte til at de kom til hotellet kl.04.00 på natten.
# Flertallet er av den oppfatning at det samme må gjelde for luftfartsloven, som bl.a.
# Klager anfører at han og sønnen ﬁkk mageproblemer allerede første dagen.
# klager har rett til erstatning av sine tilleggsutgifter på kr 1.754. Det forelå i dette tilfelle
# Reisens pris: 16.255,-
# var ingen ting gjort. De ba da om å bli ﬂyttet til annet hotell.
# problemet må skyldes en systemsvikt eller dårlig kommunikasjon mellom KLMs system
# Per Gynt Tours har anført at kunden i dette tilfelle var medvirkende til at prosessen
# Ving viser til at når gjester som reiser sammen skal ha ulik varighet på oppholdet, vil
# Dersom man skulle ta hensyn til mulig de-icing ved enhver avgang i Europa midtvinters,
# slo den av og ble rasende da de konfronterte ham med det og ba dem ﬂytte ut av
# Ving har anført at klager kontaktet guiden fordi de var misfornøyd med maten og
# Reisearrangøren er villig til å refundere eventuelle ytterligere utgifter til mat/drikke på
# Destinasjon: Egypt
# vurdering må klager da selv bære de ekstrautgifter hun ble påført.
# ble sprayet på utsiden av rommet. Siste dagen var katastrofal - da de oppdaget hva som
# informasjon på informasjonsmøtene om dette fordi de opplever at enkelte gjester ikke
# var praktisk mulig. Ved vurderingen legger ﬂertallet vekt på at mange passasjerer var
# Av Gotogates vilkår, som ble akseptert ved bestillingen av reisen, fremgår det at
# Mindretallet, forbrukernes representanter, ﬁnner på sin side at Travelpartner er mest å
# 2. Bagasje
# år var interessert i Milano tok hun med barnebarnet på turen og betalte kr.4.645,- for
# Klager anfører at ﬂyavgang Molde skulle være kl. 15.55 den 30. desember 2011.
# 3* mot 4* på det bestilte.
# Dersom klager ikke har tatt vare på kvitteringer, anbefaler nemndas ﬂertall, lederen
# rutinemessig vedlikehold. En feil som oppstår/avdekkes under normalt vedlikehold
# byggeplass like ved bungalowen de bodde i. Det var sliping og kutting av ﬂiser med
# France ikke kan lastes for at klager ikke rakk videreforbindelsen til Oslo.
# Reisens pris: kr 12.176
# og nektet ombordstigning har forskjellige formål og grunnlag, og begrensninger i en
# Reisens pris: ca. 22.000
# hatt annet formål med å gi slik beskjed, enn å assistere klager ved å rette opp feilen
# Reisens pris: 6.181,-
# Reisens pris: kr. ca.65.000,- pr person
# Hun ble dermed overlatt til seg selv og måtte ordne med hotell og ny hjemreise. Hun
# Reisens pris: kr 10.350,-
# ventetiden. Flertallet antar at hotellutgifter i Trondheim påløp som følge av uklarhet
# Mindretallet, bransjens representanter, er av den oppfatning at Norwegian ikke hefter
# Reisens pris: kr 45.915
# Reisens pris: 5.030
# Detur har anført at årsaken til at klager ble tilbudt annet hotell mot å betale ekstra, var
# inn i vilkårene for ﬂyreisen. Det er informert om hvilke regler som gjelder for
# Klager opptrer på vegne av seg selv og 13 andre som deltok på reisen. De anfører at
# klagerne til slutt valgte alternativ transport hjem.
# kompensasjon fordi klager ikke tok opp problemet med Apollos representant på stedet.
# tekniske feil, uavhengig av når feilen oppdages. Om feilen er uforutsett eller ikke, er
# Reisens pris: kr 10.380,-
# innlosjert på Koka, men i en blokk av betydelig lavere standard som visstnok hadde
# Klager anfører at hun valgte dette hotellet fordi det var opplyst at det var a/c hele
# samme antall timer avreisedagen. De har tilbudt et gavekort på kr.2000,- per familie
# enn Norwegians alternative avgang. Nemndas ﬂertall, lederen og forbrukernes
# ekstraordinær omstendighet i EU-forordningens forstand.
# ikke se bort fra at en feil kan ha oppstått. KLM har ikke søkt å dokumentere at deres
# snarest mulig. En omruting med SAS ville vært vesentlig raskere og bedre for klagerne,
# mindretall. Nemndas ﬂertall, samtlige medlemmer med unntak av bransjerepresentant
# Domstolen har også angitt en tidsgrense på at tre timer forsinkelse utløserrett til
# som ikke var oppgitt. I tillegg var de nærmeste strendene ikke egnet for den aktiviteten
# i denne forbindelse til sine internettsider som opplyser om dette. Når det gjelder air
# ﬂertall, lederen og forbrukernes representanter er av den oppfatning at det i dag ikke
# april, d.v.s. en uke senere. Ryanair har ikke kommentert dette og ﬂertallet legger
# dette rett til erstatning. Flertallet anbefaler at NSB dekker klagers tap på 307 kroner.
# Reisens pris: kr.9.640
# Klagerne anfører at de meldte seg på turen fordi den etter programmet så avslappende
# kostet så mye som klager ble avkrevd av hotellet.
# Endre billett
# Norwegian anfører at forsinkelsen skyldtes uforutsette tekniske problemer,  Herunder
# ruteendringen førte til ekstrautgifter for klager. Mindretallet viser til at beskjed om
# Air Norway har i det vesentlige anført:
# reaksjoner. Sengedyrene fulgte med hjem.
# Mindretallet, jernbaneforetakenes representanter, er av en annen oppfatning.
# størrelsesorden. Mindretallet, ﬂyselskapenes representanter er av den oppfatning at
# en ekstraordinær omstendighet i forordningens forstand. Mindretallet viser til at
# gikk til innkjøp av mat og drikke samt at de ﬁkk utgifter til telefon.
# Aerolympic booking AS har ikke svart på klagers brev.
# Bravoﬂy.com har i det vesentlige anført:
# sak 215/14F som er behandlet på dagens møte. Saken gjelder samme kansellering,
# «Oppdagerpakke» for kr.722,- og en utﬂuktspakke for kr.225,-. Informasjon om dette
# Reiseleder ville da ha gjort sitt ytterste for at barnet skulle få være med i klubben og
# Klager anfører at de - to voksne damer med to barn hver - opprinnelig hadde ønsket
# Mindretallet, de to forbrukerrepresentantene, er enig med ﬂertallet i at klageren
# dag. Mindretallet kan ikke se at klager har krav på refusjon av taxiutgifter. Etter
# den ene klagerens konto. Flertallet anbefaler derfor at det blir utbetalt kr 3.200.
# ikke.
# Reisens pris: 33.576,-
# Reisens pris: 64.380,-
# oppfatning at også en lovlig streik blant selskapets ansatte oftest vil være en
# mer sannsynlig at Norwegians kundesenter lovet å erstatte hotellutgiftene enn at det
# Nemndas ﬂertall, lederen og forbrukernes representanter ﬁnner det sannsynlig at
# Tidsrom: 150613 - 230613
# Mindretallet, ﬂyselskapenes representanter, er enig i at klager møtte frem for sent.
# Bravoﬂy.com har ikke avgitt uttalelse til klager eller nemnda.
# Sum kostnader kr 2200
# kontrollen ble foretatt, hvor kontrollen ble foretatt i forhold til avgangen fra Sandvika
# ikke er grunnlag for å frafalle gebyret. Det fremkommer etter mindretallets vurderinger
# Flertallet, lederen og ﬂyselskapenes representanter, er av den oppfatning at saken
# Klager har i det vesentlige anført:
# grunnlag for refusjon av utlegg til nye tilslutningsbilletter.
# Reisens pris: 44.500,-
# Solfaktor Pluss bemerker at kundene ankom Canifor Hotell, Qawra lørdag 28.
# at Norwegian står nærmest til å bære ansvaret for misforståelsen og anbefaler at
# mindre utgifter. Det er uklart for ﬂertallet hvor store disse ville ha vært, men ﬂertallet
# Reisens pris: kr.21.810
# Reisens pris: kr 14.080
# Turarrangør: Tyrkiareiser
# Klager anfører at ﬂyavgang etter bestillingen skulle være 26. mars kl. 0810.
# Solia har vist til at de på sine nettsider og i sin katalog anbefaler kunder med
# Reisens pris: kr 11.820
# for dette, og klager må selv bære de ekstra utgiftene.
# trykket på en knapp i sikringsskapet og da ﬁkk de strøm.
# legitimasjon.
# til standarderstatning
# erstatning etter luftfartsloven/Montrealkonvensjonen.
# erstattes.
# Reisens pris: kr 47.240
# er godtgjort at de har truﬀet rimelige tiltak for å unngå følgene av kanselleringen og er
# Klageren, på vegne av 17 deltagere på turen, har påberopt bl.a følgende forhold:
# ﬂyselskaper, og faktisk transporterende selskap. Mindretallet mener derfor at SAS vil
# Mindretallet, jernbaneforetakenes representanter, mener NSB ikke er bundet av hva
# skadefritt for at det skal være gyldig». Innsjekkingen kontrollerer bare passet som
# faktiske forhold. I løpet av klagers ferieuke var det ingen strand der i det hele tatt - selv
# Danish Air Transport(DAT) har i det vesentlige anført:
# Nemndas ﬂertall er av den oppfatning at TAP Portugal ikke hadde mulighet til å unngå
# ikke å få dem likevel. Ofte vil en slik situasjon føre til at man føler seg misfornøyd
# Oslo Lufthavn har i det vesentlige anført:
# World. Rommene hadde slitte vegg til vegg tepper, noe som ikke er særlig hygienisk.
# er den reisende som er ansvarlig for hva bagasjen inneholder.
# Mindretallet, de to reiselivsrepresentantene, er av den oppfatning at det kan gis en slik
# understreker at ﬂyplassen ligger på strekningen med et langt tidligere stoppested enn
# tilbudt noen alternativ ﬂygning eller assistanse av Ryanair, og at de ble overlatt til
# ikke ﬁkk sjekket inn innen fristen. Flertallet viser til klagers detaljerte beskrivelse
# ﬂeste var svært fornøyde. Ved å melde seg på har deltagerne godtatt betingelsene.
# gir etter dette rett til erstatning.
# ﬂertall, lederen og forbrukernes representanter, er av den oppfatning at den fremlagte
# sannsynlig at det er overensstemmelse mellom ordrebekreftelse og bestilling. Flertallet
# rimelige hensyn var truﬀet. Forsinkelsen gir etter dette rett til en standarderstatning.
# klagerne har ikke underbygget nødvendigheten av dette. Flertallet er derfor enig med
# Ving har anført at klager ikke var i kontakt med Vings representanter på stedet.
# forhånd. Når en reise bestilles på nettet, må kunden krysse av for å ha lest og akseptert
# Nemndas ﬂertall, lederen og ﬂyselskapenes representanter, legger på bakgrunn av
# jf. artikkel 9. Det er uklart for nemnda om SAS har erstattet klagernes matutgifter.
# informasjon om at dersom han sendte inn en e-post til NSB med semesterkortet som
# Ving anfører at klager først tok kontakt med Ving etter ca. 1 uke, 26. juli.
# ﬁkk. Dessuten påløp det utgifter, ca kr.500,- per person, til transport på grunn av
# en mangel dersom de er av mindre betydning og er av det slag kunden må regne med
# Reisens pris: kr.10.202
# Den opprinnelige reisen til Frankrike kostet totalt NOK 5260
# Star Tour har ikke kommentert klagen ut over å henvise til at de mener at klagen er for
# Reisens pris: kr.25.409
# antall stjerner. Det anføres videre at klageren ﬁkk tilbud om ny leilighet allerede
# inklusive.
# ordinære drift og det må settes av tid til dette ved utarbeidelsen av ﬂyplaner.
# Widerøe har til klager opplyst at WF263 ble kansellert grunnet sykdom blant crewet.
# morgenen og kl 03.00 på natten. Det er ikke konstatert noen feil på anlegget på rommet
# at passasjerene ved innstilling av en ﬂygning har valget mellom refusjon av
# en ferie forsvinner når man mistrives med boforholdene.
# Continental Airlines har i det vesentlige anført:
# Oska Travel har opplyst at dette var et helt nytt reiseprodukt hvor enkelte deler av
# bassengområde med solsenger og ﬂere bassenger.
# vogn før kontrollen fant sted og det anbefales at gebyret frafalles.
# refusjon av skatter og avgifter, kun kan tilsvare Tripmonsters reelle kostnader med å
# Klagerne, på vegne av tre bestillingsnummer med i alt 10 personer, anfører at Ving har
# turarrangørs lokale representant.
# Norwegian Holidays har i det vesentlige anført:
# Detur har vist til sine reisevilkår og at kunden ikke har tatt opp sine klagepunkter med
# Star Tour har anført at ﬂyet ble forsinket fra Gardermoen på grunn av en teknisk feil
# hans adresse i Mehamn og deretter tilbake til Gardermoen 23. mars og utkjørt til klager
# Klager anfører at leiligheten han ﬁkk hadde lav standard med fuktighet i sengetøy og
# Hamar Feriecenter har i det vesentlige anført:
# Nemndas mindretall, forbrukernes representanter er av den oppfatning at Solfaktors
# hunden og at tilfredsstiller kravene i vilkårene. Flertallet viser til at klager har fremlagt
# Nemndas mindretall, forbrukernes representanter, er av den oppfatning at klager i
# Albatros og med avreise 15. juni. I mai ble de informert om at hotellet var overbooket
# var ingen hjelp å få fra Ving.
# Reisens pris: ca. 63.000
# forhåndsbetalte maten fordi de ikke ﬁkk lov til å ta med mat til henne på rommet
# således ikke anledning til å orientere seg og eventuelt oppsøke betjent vogn for å kjøpe
# regelverk. Klager har valgt full refusjon av den ubenyttede billetten med Widerøe, og
# Maur krøp rundt vask og toalett og alle måltider måtte derfor spises ute.
# Klagers datter ﬁkk individuell rådgivning om at visum ikke er nødvendig til Mexico. Som
# Nemndas mindretall, forbrukernes representanter ﬁnner det etter en samlet vurdering
# Norcopia San Augustin. Guiden ved ankomst bestemte så at de begge skulle bo på
# og hvis en velger å bo tre på et slikt rom, blir det mindre plass. Det gis derfor rabatt for
# Ving Norge. Ving Norge kan ikke se at reisearrangøren skal refundere klageren
# således etter mindretallets vurdering ikke rett til standarderstatning.
# Widerøe tilbød omruting dagen etter. Widerøe har ikke kommentert hvorfor klager ikke
# pakkereiseloven § 6-4, og at klageren kan kreve erstatning av arrangøren for det tapet
# Nazar har anført at dets personale som ledd i kvalitetskontrollen har besøkt hotellet
# som dato alternativ». Dersom Star Tour AS representant hadde vært mer årvåken,
# Reisens pris: kr 29.389
# sannsynliggjøre tapet på annen måte, anbefaler nemndas ﬂertall, lederen og
# Les mer om vilkårene her:»
# som med rimelighet kan kreves for å unngå tapet, og at forsinkelsen således gir rett til
# kokeplate var defekt, kranen umulig å skru opp, a/c virket ikke.
# Turarrangør: Via Tours
# Solfaktor har anført at det er vanlig med kakerlakker på Gran Canaria på grunn av
# foreliggende opplysninger godtgjort at kanselleringen skyldtes en ekstraordinær
# Klager representerer 2 familier. I tillegg til at de ved ankomst ﬁkk tildelt mindre
# dekkende for det produktet som klageren endte opp med. Det foreligger da et brudd på
# de hadde å forholde seg til var datterens hjemlengsel, det var ingen andre konkrete
# representanter på plass, eller i tide til at de ﬁkk muligheten til å hjelpe under
# Klager anfører at de hadde bestilt en 3-roms leilighet med havutsikt på et høyt ranket
# påberope seg mangler. Det fremgår av logen til den stedlige representant at klager tok
# klager anført at det både på nettsidene og på billetten er opplyst at middag ikke
# fordi de ønsket å bo på eller helt inntil en golfbane. Planen var at han skulle gå mange
# EC 261/04 (EU forordning 261/2004) ikke gir noen anvisning på utbetaling av en
# henvisning så lenge kunden blir hjulpet via kontaktinformasjonen som oppgis.
# klager måtte kunne slå seg til ro med dette svaret i det det etter angitt tid ville være
# Reisens pris: 26.070 nok.
# Apollo har vist til at klager ikke tok problemet opp med dem.
# grunn kundens påstand om at han tok kontakt den 18. juni.
# Nemndas mindretall, ﬂyselskapenes representanter, er av den oppfatning at kravet
# barnevennlig familiehotell. Junior suite, som vi hadde bestilt på Royalton Hicacos
# etter sopp på badet. Klager tok ikke kontakt med Ving på reisemålet. Ving ﬁkk ikke
# ledig kapasitet på reisemålet, og går ut fra at arrangøren har gjort sitt ytterste for å
# luftfartslovenden/Montrealkonvensjonen delt seg i et ﬂertall og et mindretall.
# Virke Reise Utland, er av den oppfatningen at informasjonen som ble gitt over
# gal beliggenhet. Detur ser ikke at det er grunnlag for kompensasjon
# denne vurdering i tvil.
# person. Flertallet anbefaler at Norwegian utbetaler standarderstatning.
# Reisemål: Cruise vestre Middelhavet
# norske. Sykdommen var forårsaket av bakterien shigelle sonnei.
# eller ulempe for ham. Avhjelpen må skje innen rimelig tid og uten vesentlig ulempe
# om ripene helt eller delvis er påført under denne transporten. Flertallet er videre av
# Reisens pris: Kr. 27.805
# Star Tour anfører at det ikke er uvanlig at gjester får mageproblemer i Syden på grunn
# Reisens pris: 43.232,-
# Star Tour anfører at den tilbudte kompensasjon på kr.3.300,-, eller gavekort på
# overraskende. Studentrabatt er vanligvis universell og er ikke knyttet opp til et mindre
# Ving har vist til at det i hotellinformasjonen er opplyst at hotellets treningsrom er
# rimelig grunn for å forlenge klagefristen.
# Klagerne anfører at de etter ankomst ﬂyplassen den 15/2 først hadde problemer med
# underskrift aksepterer forsikringen, må han selv dekke kostnadene.
# besetningsmedlem må melde forfall.
# Klager anfører at da hun bestilte, ba hun om å ikke bli plassert inne i kroken på
# Turarrangør: Lilleput Reiser AS
# fra Oslo S». Det er ikke angitt noe klokkeslett på gebyrslippen som ble skrevet ut.
# ﬂyselskapets rullestol og at hans egen stol ville bli sendt som bagasje.
# ha klaget til Star Tour ﬁkk de rom på annet hotell mot å betale 300 euro. Beløpet kreves
# for ulemper med insekter o.l. For problemene med kloakken og dårlig renhold ved
# skulle være barnevennlig, noe som ble bekreftet. Dette stemte ikke. Klagers barn kan
# Klageren skulle reise fra Oslo til Gran Canaria den 20. november 2013 kl. 07:30 med
# seg gjennom to linker på NSBs hjemmeside for å ﬁnne ut at NSB har forskjellige vilkår
# dette tidspunkt allerede begynt å bli vanlig. ebookers mangelfulle informasjon førte til
# representant for Thai Airways opplyste til klager at det var i orden at hun droppet
# Destinasjon: Costa Brava
# ﬁskingen etter ankomst torsdag. Det er videre anført at markedsføringen fremstår som
# ikke er det samme som en ekstraordinær omstendighet. Etter mindretallets
# antar at Norwegian har avtaler med hoteller med gode priser i slike tilfeller.
# ikke bare påregnelig i vintermånedene, det er også hensiktsmessig både for selskap og
# hotellenes beliggenhet ellers ville være vanskelig å få kjøpt middager.
# ﬂyselskapenes representanter, er av den oppfatning at forsinkelsen ikke gir grunnlag
# Reisens pris: 12.930,-
# EF har overfor klageren anført at de på forhånd gjorde oppmerksom på at en
# ...
# for å behandle den. De beklager at det var gitt feil informasjon om underholdningen.
# Nemndas ﬂertall, nemndas leder og ﬂyselskapenes representanter, har forståelse for
# og behagelig ut. Det viste seg imidlertid allerede første dagen at noe var galt. Etappen
# Amisol har vist til at slike vanndispensere er helt vanlige, og det var ingen feil ved dem
# tilfellet. Det fremkommer av korrespondansen mellom klager og Supersaver at
# Reisens pris: 22.920
# bestillingssystemet automatisk legger inn minimum forbindelsestid mellom to
# Rommet ble gjennomsøkt og ingen spor av veggelus eller insekter ble funnet.
# Oslo Lufthavn AS har i det vesentlige anført:
# EF har i det vesentlige anført:
# Reisens pris: 9.780
# for å ilegge gebyr var således til stede.
# til Tyskland og Polen. Totalt antall deltagere var 145.
# Reisens pris: ca. 31.430
# at konserten med gjesteartister var 4. august og ikke 2. august som klager hadde
# hadde mulighet til å påvirke at klager reserverte samme reise to ganger. Klager bestilte
# selskap på lørdag til en mye høyere pris. Klager eier en leilighet han bodde i fra fredag
# var dyrere enn bestilt.
# Badet var lite og i dårlig stand. Nøkkelkortene måtte stadig byttes fordi de ikke virket.
# Nationaltheatret stasjon. Klager betalte reisen med sin iPhone. I telefonens display sto
# dødsfall. Legeerklæring kreves.
# hun innrettet seg etter det råd hun ﬁkk. Det har etter mindretallets vurdering
# da forskuttert deler av reisen, noe de gjorde fordi fru B er ansatt hos Berg-Hansen.
# Når det gjelder den nærmere vurdering har pakkereisenemnda delt seg i et ﬂertall og
# Lufthansa har ikke avgitt uttalelse til nemnda. Til klager har Lufthansa i det vesentlige
# klærne på - og med beliggenhet utenfor all sivilisasjon.
# kr.1.280 - dvs kr.490,-per person.
# Lowcostholidays hevder at de ikke ble informert om at hotellet ikke kunne ta imot
# eller hagl.
# ble påført.
# uten at det hjalp. Klager har fått ødelagt store deler av dagene ved bassenget fordi hun
# denne saken reiste sammen og forholdene i de to sakene er identiske.
# vesentlige anført:
# Tidspunkt: 050112 - 120112
# Reisens pris: nok. 7.510
# var stilt i Sturgeon saken. Generaladvokaten har også angitt en tidsgrense på at tre
# Reisens pris: 10.646
# forsinkelsen ikke gir rett til erstatning.
# Klager anfører at de i januar 2011 bestilte tur til Byala Beach Ressort i Obsor.
# Hotellet hadde siden juni hatt problem bakterier/virus - noe Ving ikke
# ﬁnner videre godtgjort at kanselleringen av klagers ﬂygning ikke kunne vært unngått
# opp matstandarden med Ving. Vanligvis får man ikke kansellere bestilt all inklusive,
# Hansen, bemerker for øvrig at det på bakgrunn av de foreliggende opplysninger kan
# Turarrangør: Tellus Reiser
# Reisens pris: 28.000,-
# Star Tour har tilbudt et prisavslag på kr.3.000,-, alternativt et reisegavekort på kr.4.000,-
# til Tyrkia og ingen andre klaget.
# Klager anfører at de var en familie på 11 personer som hadde bestilt 4 rom. Rommene
# Reisens pris: kr 19.577
# Klager anfører at han hadde bestilt hotell med halvpensjon på Hotel Marina Bay  View.
# Klager anfører at de bestilte reisen hos et reisebyrå som kunne anbefale et godt
# alternativer med andre selskap (Norwegian).
# oppfylt sin informasjonsplikt i denne saken. Det er ikke å forvente at et reisebyrå
# forsinkelsen streik blant selskapet piloter.
# velger å avbestille innen 24 timer, all den tid Supersaver kun får deler av beløpet
# Tvert imot er det naturlig å forstå punkt 8 i vilkårene slik at Solia bare kan kansellere
# Norwegian har vist til at de har gitt informasjon om at de reisende må sette seg
# oﬀentlig transportmiddel - taxi, noe de ellers ville hatt krav på å få dekket. Flertallet
# klagen. I korrespondansen med klageren har de bare anført at de ikke kan dekke noe
# 2. Fredag den 6. desember 2013 skulle klager reise med DY620 fra Oslo til Bergen kl.
# var på pilegrimstur og skulle gå lange dagsmarsjer hver dag. Klær og utstyr som var
# var, og det var ikke i nærheten av hotellet.
# dette bare en forespørsel som han var ubundet av.
# derfor Apollo for råd om passende hotell. Valget falt på Three Corners Ocean View.
# Reisens pris: 52.290 nok
# Etter å ha sett på saken vil arrangøren likevel i dette tilfellet refundere deler av reisen.
# I e-post til Ving natt til 27. desember opplyste klager at lukten var like ille.
# november 2013, klages det også over.
# fremkommer av de alminnelige vilkår for pakkereise punkt 5.2. første og annet ledd.
# holdt det bare 17-18 grader. Med en bade syk 11-åring fra Tromsø ble dette en vesentlig
# reiseplanen om at en enkelt ﬂygning opereres av et annet selskap kan etter ﬂertallets
# Jystad, ﬁnner å måtte legge til grunn at årsaken til forsinkelsen lå utenfor selskapets
# Eventuell prisdiﬀeranse mellom opprinnelig og ny billettpris kommer i tillegg.
# medisiner, brille, mobiltelefon i sin innsjekkede bagasje.
# tilsvarende transportvilkår, til bestemmelsesstedet, jf. forordningen artikkel 5, jf.
# EU261/04- (EU forordning 261/2004) det ble vurdert men avvist, og videre slått fast i dom
# Widerøe ikke har godtgjort at kanselleringen skyldtes ekstraordinære omstendigheter
# KinaReiser har i det vesentlige anført:
# stikkontakt hang løst ut av veggen. Andre norske gjester som bodde der, hadde ikke
# på 30% av reisens pris etter fradrag av tidligere utbetalt avslag.
# selv om alle rimelige tiltak var truﬀet. Flertallet viser til at det ikke er samme feil
# nytt hotell, men måtte betale mellomlegg for å få det. De krever full kompensasjon.
# leilighet etter ankomst at hun syntes leiligheten var for liten.
# Reisens pris: 12.279,-
# Turarrangør: Norwegian
# og nektet ombordstigning (artikkel 4) gir ikke forsinkelse i artikkel 6 noen anvisning på
# Klager hadde da avkreftet dette. Den 20. august hadde klager tatt kontakt med
# Klager ble påført utgifter til nye billetter med Norwegian på neste ﬂygning. Om dette
# Mindretallet, forbrukernes representanter ﬁnner ikke godtgjort at
# hotellet 2 dager før hjemreise er det likeledes opplyst at hjemreise er 16. juli kl.04.30
# Nemndas ﬂertall, lederen og forbrukernes representanter, ﬁnner det på bakgrunn av
# Atira anfører at det i telefonsamtalen med klager 29. juni ble informert om at den elven
# og at de i stedet ﬁkk rom på Riu Bonanza Park. Dette hotellet hadde ikke samme
# Klager anfører at de hadde bestilt dobbeltrom med ballkong og havutsikt.
# Klager anfører at de 11. oktober 2011 bestilte en reise til Spania som skulle foregå fra 3.
# Av Travelpartners vilkår, som ble akseptert ved bestillingen av reisen, fremgår det at
# mellom klager og salgskontoret, og mellom salgskontoret og kursleder. Det eneste
# Reisens pris: 11.100,-
# Apollo har henvist til vilkårene for uspesiﬁserte reiser. Av disse fremgår at man kan
# Tide Reiser har i det vesentlige anført:
# rengjøring andre dagen og ikke toalettpapir.
# Via Travel, Hamar har i det vesentlige anført:
# Nemndas ﬂertall, lederen og forbrukernes representanter, er av den oppfatning at det
# forvente at systemet ﬁnner frem til reiser til Oslo, Gardermoen, når systemet tillater
# Ving har anført at ved uspesiﬁsert reise gjelder følgende i henhold til vings vilkår:
# Nemndas ﬂertall, lederen og turarrangørenes representanter, ﬁnner det på bakgrunn
# opplyst at det var €6,50 per dag. Han anser dette som et avvik fra kontraktens grunnlag
# Travellink har anført at klager reklamerte til Norwegian først 3 måneder etter
# Apollo har beklaget at rommet ikke var rengjort ved ankomst og at bostedet ikke var av
# omstendighet som ikke kunne vært unngått selv om alle rimelige tiltak var truﬀet.
# Antall reisende: 6
# Air Berlin har i det vesentlige anført:
# kostet. Etter ytterligere kontakt pr. mail, ﬁkk han 8. oktober oversendt bekreftelse
# Reisens pris: kr.13.180
# ca. 10 sekunder før han leste oppslaget om at han var i en ubetjent vogn, og at han da
# klagers utlegg.
# både til strand (20m) og til sentrum (300m). Etter ankomst lørdag fant hun fort ut at
# Nemnda har ved vurderingen av saken delt seg i et ﬂertall og et mindretall. Flertallet,
# Reisens pris: 8.639
# Reisens pris: 34.991,-
# gratis (kunden hadde billetter for økonomiklasse på SAS. SAS serverer ikke gratis mat
# Reisens pris: Kr. 12.300 pr stk
# rimelig tiltak var truﬀet. Slike omstendigheter kan særlig inntreﬀe med politisk
# klagers endring kun bekreftet at prisen på de valg klager ønsket å gjøre var riktig, og
# Travellink har anført at kunden ikke tok kontakt om sitt problem og Travellink ﬁkk
# Nemndas mindretall, reiselivsbransjens representanter, er uenige i at det er snakk om
# mellom kjøpesummen for den første reisen kr 14.500 og kr 16.500 den nye reisen. I
# til kjøp av nye billetter, alternativ transport mv. Forsinkelsen gir etter dette rett til
# Amisol anfører at kakerlakker ikke er uvanlig på Tenerife og i syden ellers.
# 650 euro, samt tilbakebetalingen av utlegget til A/C.
# Stressless-stol fra Ekornes til moren. Dette kunne de ikke etterkomme, men etter
# hjemmeside eller annet steds. Klagerne har opplyst at de ikke på noe tidspunkt ble
# fremkommer tydelig i mailen fra SAS datert 10. juni 2013 at man skal undersøke
# at klager reiste til Gardermoen på egenhånd. Flertallet viser til klagers brev og til
# Etter dette legger nemndas ﬂertall til grunn at feilen oppsto uten forvarsel til tross for
# Twice Vinreiser og opplevelser har i det vesentlige anført:
# intravenøs behandling. De ﬁkk bytte til annet rom, men det var like ille.
# Reisemål: Tyrkia, Alanya.
# adskilte soverom fordi de har 2 barn på henholdsvis 13 og 4 år. For dette betalte de
# tilsvarer 4* standard. Hotellet bruker uavhengig laboratorium for tester av mat og
# Deturs kundekonsulent og hans overordnede. Kundekonsulenten gikk ut over sine
# passasjerer som nektes ombordstigning mot sin vilje skal gis en standarderstatning
# Tidspunkt: 011111 - 231211
# hjemreisen, og de krever derfor kr.716,- refundert.
# Klager anfører at da de ankom, ﬁkk de en leilighet med ett bad, men de hadde bestilt
# forutsigbart at en passasjer skal videre med ﬂy dersom han/hun har kjøpt en billett til
# Nemndas mindretall, Flytogets representant, ﬁnner det mest sannsynlig at kontrollen
# Ving anfører at klager ikke tok kontakt med deres representant under oppholdet før på
# Reisens pris: 14.500,- pr voksen
# markbalkong. Ved ankomst ﬁkk han rom med markbalkong på et hotell som ikke kan
# ugyldig pass, manglende visum, vaksinasjoner eller andre påkrevde dokumenter får du
# Turarrangør: Route66USA
# ikke er berettiget til å belaste klager med et gebyr for i dette tilfellet. Forbrukernes
# kvalitetsmålinger i spørreskjema etter hjemkomst. I følge hotellet var det bare det ene
# det vesentlige anført:
# da hun ble ilagt kontrollgebyr. Flertallet viser til klagers opplysninger om at hun var
# ﬂyselskapets kontrollsfære. Mindretallet er følgelig av den oppfatning at klager har rett
# viste seg å være 2* med små basseng, langt fra sentrum og ingen barn eller aktiviteter.
# Detur anfører at moskitoer er veldig vanlig i Egypt og kløen er sterkere enn det vi er
# betaler. Vår pakkeinkluderer altså 4 lunsjer, 4 middager og 4 frokoster!»
# Reisens pris: 18.590
# på et 4* hotell. Det ene rommet manglet ordinære senger - i stedet var det satt inn to
# utgangspunktet kun rett til omruting på tilsvarende transportvilkår, og drosjeutgiftene
# Det fremgår av NSBs transportvilkår § 4 C at kjøp og validering av elektroniske billetter
# Bardufoss Lufthavn - til Evenes Lufthavn- klagers bestemmelsessted. Norwegian har
# «goodwill» kompensasjon.
# Aeroﬂot-Nord har ikke besvart Flyklagenemndas henvendelse av 19. oktober 2009.
# tilbake på dette selv om kundekonsulenten hadde gjort en feil. Nemnda kan ikke
# burde oppsøkt informasjonen slik det ble oppfordret til. Det fremkommer også av
# reise hjem. Kursleder prøvde å motivere henne til å bli, og det var kommunikasjon
# registrert som hovedreisende. I dette tilfellet var SMSen fra innklagede heller ikke
# Nemnda ﬂertall er av den oppfatning at Norwegian i dette tilfellet ikke hadde
# nemlig at man ikke kan ﬂytte gjester som ikke har bestilt markbalkong til en leilighet
# rommet samme dag som klager hadde tatt kontakt.
# have to accept that things will not be the same here as they are back in Norway and we
# Ving anfører at sykdom på reise kan inntreﬀe. Ofte skyldes urinveisinfeksjoner og
# Nemndas mindretall, reisebransjens representanter, er av den oppfatning at det er
# klager, han valgte derfor etter anbefaling fra Norwegian å kjøpe ny billett med annet
# De så dem på området og var på hils. Klager har vært i kontakt med sin sønn og han
# Rolf Forsdahl, Reiselivsdirektør HSH
# må betales direkte til hotellet.
# hensikt å gjøre det.
# Norwegians har i det vesentlige anført:
# som nemndas ﬂertall avrunder til kr 4.700. Det er opplyst at det er overført kr 1.500 til
# til å ﬁnne ut av hva som tilbys og hva prisen for de forskjellige alternativene er.
# ved forsinkelser dersom «han selv og hans folk har tatt alle forholdsregler som med
# forsinkelsen.
# opplysninger til grunn at klager har kjøpt billetten på Lufthansas hjemmeside, at hun
# Reisens pris: kr 19.740
# Reisebetingelsene lå ved, og disse aksepterte hun. Reiserådgiveren ﬁkk navnene på
# opplysninger eller på annen måte sannsynliggjort at skaden skyldtes «reisegodsets
# 1. Klager skulle reise fra Oslo til Bergen den 22. november 2013 kl. 16:20 med DY620. Det
# Sak nr.: 48/11
# oppfatning av klagerne har rett til en standarderstatning på 400 euro per person.
# en ekstra stopp på Bahamas og ankom først kl. 11.00.
# Reisens pris: nok. 11.245
# side i en slik situasjon kun kan tilsvare selskapets reelle kostnader med å gjennomføre
# i bestillingsbekreftelsen etc. Det er frivillig å kjøpe pakken, og det er alltid noen som
# lufttrykket om bord. Feilen lot seg ikke utbedre av teknikere på stedet, og en tekniker
# kostet ny kr 7490. Vognens alder tilsier etter ﬂertallets vurdering at det gjøres et ikke
# innkommet ﬂy som følge av akutt sykdom hos kapteinen.
# bagasje ble derfor tatt av. Klagers bagasje ankom Gardermoen 22. mars og ble sendt til
# Reisens pris: kr.6 515
# som lover raskt bytte av hotell. Dette trakk ut, før de ﬁkk nytt hotell siste uken mot å
# stadighet skittent.
# Reisens pris: 12.580,-
# ugyldig billett slettes.
# Solia har vist til at det oppsto en teknisk feil ved oppdatering av prisene.
# mangler ved reisen som ikke ble avhjulpet på en tilfredsstillende måte.
# Reisens pris: 81. 330 nok
# tilfelle har foretatt innkjøp ut over det som anses som nødvendig.
# badet. Klager krever full refusjon av reisens pris.
# Turarrangør: Sembo AB
# Reisens pris: 15.360,-
# ekstraordinær omstendighet i EU-forordningens forstand. I dette tilfellet var det
# er av den oppfatning at klager har rett på erstatning for ødelagt bagasje.
# mulig å reversere endringen. Klager endte opp med å kjøpe en ny billett til kroner 1
# Klager anfører at de hadde bestilt rom på Barcelo Jandia Mar. Lørdag før avreise ringte
# for at buret ikke tilfredsstiller kravene. Denne bevisbyrde er ikke oppfylt i saken, og
# ikke registrert noen henvendelse fra klager.
# Detur har anført at det i høysesongen må forventes støy fra andre gjester, men har
# billetten og må således selv bære ansvaret for den merutgift hun ble påført.
# representant 18. juni og ble enige om at de skulle gå direkte til resepsjonen.
# er kommet frem. Flertallet er av den oppfatning at Travelstart i dette tilfellet ikke har
# som gikk fra klager gikk om bord i toget til ankomst Ski stasjon, mener ﬂertallet at
# hotellets forsikring. Ethvert hotell må ha en forsikring, og ﬂertallet går uten videre ut
# team require to take Lo (Liaison oﬃcer) local/non-local, for above 6 participants and
# til Rådhusplassen. Klager er usikker på bussen hun er i ferd med å gå om bord i, går
# derfor gjøres fradrag for den slitasje og verdiforringelse ellers som bruken av den
# Klager anfører at rommene på hotellet var en katastrofe. Det var 4-5 kakerlakker hver
# Flertallet, nemndas leder og forbrukernes representanter, ﬁnner det mest sannsynlig
# ble han i løpet av prosessen henvist til den norske agenten Cruise.no. Han ﬁkk
# inklusive pakke til € 228 (kr.1730,-) + € 5 (kr.40,-) ekstra ved betaling med kredittkort.
# Dette må anses for kjent. Klagerne har videre ved kjøpet av reisen akseptert Finnairs
#
# Totalt unike linjer med uthevet skrift funnet: 11753

# %% [markdown]
# Resultatet er betryggende. Vi har analysert 7827 vedtak og sitter igjen med kun 41 forskjellige overskrifter. Det tyder på fast struktur i vedtakene. Mange av disse overskriftene er variasjoner av det samme med et tillegg av en dato. Her kan vi med tanke på parsingen fjerne datoen slik at alle disse blir like. Etter å ha fjernet variasjonen med dato, står vi igjen med 15 ulike overskrifter. Fire av disse er tittel på vedtakene:
# - Vedtak i Pakkereisenemnda
# - Vedtak i Transportklagenemnda - Fly
# - Vedtak i Transportklagenemnda - Sjø
# - Vedtak i Transportklagenemnda - Kollektivreiser
#
# I pdf-en er overskriften til Transportklagenemnda - Kollektivreiser delt over to linjer. Derfor kommer den opp både som "Transportklagenemnda" og som "- Kollektivreiser". Fjerner vi også disse titlene, står vi igjen med bare 10 overskrifter til innhold i vedtaket.
#
# For å vite om det er variasjon mellom vedtakene i bruken av overskrifter, dvs. om alle overskrifter er med i alle vedtak, kjører vi en sjekk også på dette. Vi lagrer da alle overskrifter for et vedtak i en liste, så sammenligner vi listene og sjekker hvor mange forskellige lister vi får.

# %%
import os
from pdfminer.high_level import extract_pages
from pdfminer.layout import LTTextContainer, LTTextLine, LTChar
from collections import defaultdict

def extract_text_with_font(pdf_path):
    text_info = []

    for page_layout in extract_pages(pdf_path):
        for element in page_layout:
            if isinstance(element, LTTextContainer):
                for text_line in element:
                    if isinstance(text_line, LTTextLine):
                        first_char = next((char for char in text_line if isinstance(char, LTChar)), None)

                        if first_char is not None and "Bold" in first_char.fontname:
                            line_text = text_line.get_text().strip()

                            # Sjekk starten av teksten og anvend forhold
                            if line_text.startswith("Tjenesteyter følger ikke vedtaket i saken"):
                                text_info.append("Tjenesteyter følger ikke vedtaket i saken")
                            elif not (line_text.startswith("Vedtak i") or line_text.startswith("- Kollektivreiser")):
                                text_info.append(line_text)

    return text_info

def main(directory_path):
    all_pdfs_bold_lines = []
    list_occurrences = defaultdict(int)

    for filename in os.listdir(directory_path):
        if filename.endswith('.pdf'):
            full_path = os.path.join(directory_path, filename)
            bold_lines = extract_text_with_font(full_path)
            if bold_lines:  # Bare legg til ikke-tomme lister
                # Konverter liste til en tuple slik at den kan hashes for ordboken av forekomster
                bold_lines_tuple = tuple(bold_lines)
                all_pdfs_bold_lines.append(bold_lines_tuple)
                list_occurrences[bold_lines_tuple] += 1

    unique_lists = set(all_pdfs_bold_lines)

    print("\nAntall unike lister: ", len(unique_lists))
    for unique_list in unique_lists:
        print("\nElementer i den unike listen:\n-----------------------")
        for item in unique_list:
            print(item)
        print("\nAntall PDF-er med denne unike listen: ", list_occurrences[unique_list])

if __name__ == "__main__":
    directory_path = "./pdfs" 
    main(directory_path)
# Out:
# Antall unike lister:  2
#
# Elementer i den unike listen:
# -----------------------
# Sammendrag
# Dato
# Saksnummer
# Tjenesteytere
# Klager har i det vesentlige anført
# Tjenesteyterne har i det vesentlige anført
# Nemnda bemerker
# Vedtak
# Nemndas representanter
#
# Antall PDF-er med denne unike listen:  7714
#
# Elementer i den unike listen:
# -----------------------
# Tjenesteyter følger ikke vedtaket i saken
# Sammendrag
# Dato
# Saksnummer
# Tjenesteytere
# Klager har i det vesentlige anført
# Tjenesteyterne har i det vesentlige anført
# Nemnda bemerker
# Vedtak
# Nemndas representanter
#
# Antall PDF-er med denne unike listen:  113

# %% [markdown]
# Dette er gode nyheter! Vi finner bare to sett med ulike overskrifter i alle de 7827 vedtakene, og det eneste som skiller dem, er om de er innledet med «Tjenesteyter følger ikke vedtaket i saken». Det gjør det forholdsvis enkelt å parse dokumentene og lagre dem i strukturert form.

# %% [markdown]
# ## Parsing av vedtak
#
# Neste trinn er å parse vedtakene i deres enkelte bestanddeler. Vi bruker da informasjonen om overskrifter vi har samlet inn (se over): Alle vedtak har de samme overskriftene med to unntak:
# 1. Enkelte vedtak har en innledende del med informasjon om at «Tjenesteyter følger ikke vedtaket i saken». Her må vi sjekke om vedtaket har en slik innledende del. For vedtak som har en slik del, må vi lagre teksten. Det kan også være greit å ha en enkel måte å filtrer på vedtak som har en slik del. Vi oppretter derfor en bolsk variabel `Tjenesteyter_avviser_bool` og lagrer verdiene `True`og `False`.
# 2. Etter et slikt eventuelt svar fra tjenesteyter kommer overskriften på vedtaket.  Der står det om vedtaket er fattet av Transportklagenemnda eller Pakkereisereisenemnda. Det står også om det er Transportklagenemndas avdeling for "Fly", "Sjø", "Kollektivreiser". Denne informasjonen lagrer vi i variabelen `Nemnd`. Den kan ha fire ulike verdier "Fly", "Sjø", "Kollektivreiser", "Pakkereisenemnda".
#
# Vi legger også inn hele vedtaktsteksten under nøkkelen «Vedtak_komplett». Det gjør det lettere å legge inn de komplette vedtakene i en database og bruke resten av den parsede informasjonen som metadata.

# %%
import os

headings = [
    "Sammendrag",
    "Dato",
    "Saksnummer",
    "Tjenesteytere",
    "Klager har i det vesentlige anført",
    "Tjenesteyterne har i det vesentlige anført",
    "Nemnda bemerker",
    "Vedtak"
]

def parse_vedtak(file_path, headings):
    """
    Parser et vedtak og returnerer en dictionary med overskrifter som nøkler og tekster som verdier.
    """
    content = {heading: "" for heading in headings}  # Initialiser alle overskrifter med tomme strenger
    content["Tjenesteyter_avviser"] = ""  # Initialiser denne nøkkelen med tomt innhold
    content["Nemnd"] = ""  # Initialiser denne nøkkelen med tomt innhold
    current_heading = None
    nemnd_keywords = ["Fly", "Sjø", "Kollektivreiser", "Pakkereisenemnda"]  # Nøkkelord å søke etter

    with open(file_path, 'r', encoding='utf-8') as file:
        full_text = file.read()  # Read the entire content of the file at once
        lines = full_text.split('\n')  # Split the content by line for further processing        
        for i, line in enumerate(lines):
            # Sjekk for spesiell overskrift
            if line.startswith("Tjenesteyter følger ikke vedtaket i saken"):
                content["Tjenesteyter_avviser"] += line  # Lagre denne linjen under den nye nøkkelen
                continue  # Hopp over resten av løkken for denne linjen

            # Sjekk for ett av Nemnd-nøkkelordene
            if any(keyword in line for keyword in nemnd_keywords):
                content["Nemnd"] = next((keyword for keyword in nemnd_keywords if keyword in line), "")
                continue  # Hopp over resten av løkken for denne linjen

            # Eksisterende logikk for overskrifter og innhold
            if line.strip() in headings:
                current_heading = line.strip()  # Denne linjen er en overskrift, oppdater gjeldende overskrift
            elif current_heading is not None:
                content[current_heading] += line  # Legg til tekst under gjeldende overskrift


    # Etter å ha behandlet alle linjene, sett boolsk flagg basert på innholdet under "Tjenesteyter_avviser"
    # Dette er strengt tatt en gjentagelse av informasjon, men gjør det lettere å bruke databasen senere.
    content["Tjenesteyter_avviser_bool"] = bool(content["Tjenesteyter_avviser"])
    
    content["Vedtak_komplett"] = full_text.strip()  # Add the full text of the file to the dictionary


    if not content["Nemnd"]:  # Hvis ingen nøkkelord ble funnet, skriv ut en feilmelding
        print(f"Feil: 'Nemnd'-nøkkelord ikke identifisert i filen {file_path}")

    return content



def main(directory_path, headings):
    all_files_content = []

    for filename in os.listdir(directory_path):
        if filename.endswith('.txt'):
            full_path = os.path.join(directory_path, filename)
            file_content = parse_vedtak(full_path, headings)
            all_files_content.append(file_content)

    return all_files_content


directory_path = './transportklagenmnda_txt/'
# Liste over overskrifter å søke etter i filene

parsede_vedtak = main(directory_path, headings)

# %%
# NY logikk

import os

headings = [
    "Sammendrag",
    "Dato",
    "Saksnummer",
    "Tjenesteytere",
    "Klager har i det vesentlige anført",
    "Tjenesteyterne har i det vesentlige anført",
    "Nemnda bemerker",
    "Vedtak"
]

def parse_vedtak(file_path, headings):
    content = {heading: "" for heading in headings}
    content["Tjenesteyter_avviser"] = ""
    content["Nemnd"] = ""
    current_heading = None
    nemnd_keywords = ["Fly", "Sjø", "Kollektivreiser", "Pakkereisenemnda"]

    
    
    in_optional_start = False

    with open(file_path, 'r', encoding='utf-8') as file:
        full_text = file.read()
        lines = full_text.split('\n')

        for i, line in enumerate(lines):

            # Check for special header start
            if line.startswith("Tjenesteyter følger ikke vedtaket i saken"):
                in_optional_start = True

            # If we are in the optional start, keep adding lines until "Vedtak i" is found
            if in_optional_start:
                content["Tjenesteyter_avviser"] += line + '\n'  # Add a newline for formatting
                if "Vedtak i" in line:
                    in_optional_start = False  # Exit optional start mode

            # Identify "Nemnd"
            if "Vedtak i" in line and not content["Nemnd"]:
                # Check current line for nemnd keyword
                for keyword in nemnd_keywords:
                    if keyword in line:
                        content["Nemnd"] = keyword
                        break  # Exit the loop once keyword is found

                # If Nemnd is not found on the current line, check the next line
                if not content["Nemnd"] and (i+1) < len(lines):
                    next_line = lines[i+1]
                    for keyword in nemnd_keywords:
                        if keyword in next_line:
                            content["Nemnd"] = keyword
                            break

            elif line.strip() in headings:
                current_heading = line.strip()
            elif current_heading is not None:
                content[current_heading] += line + '\n'
        
        content["Tjenesteyter_avviser_bool"] = bool(content["Tjenesteyter_avviser"].strip())
        content["Vedtak_komplett"] = full_text.strip()

        if not content["Nemnd"]:
            print(f"Error: 'Nemnd' keyword not identified in file {file_path}")

    return content

def main(directory_path, headings):
    all_files_content = []

    for filename in os.listdir(directory_path):
        if filename.endswith('.txt'):
            full_path = os.path.join(directory_path, filename)
            file_content = parse_vedtak(full_path, headings)
            all_files_content.append(file_content)

    return all_files_content


directory_path = './transportklagenmnda_txt/'
# Liste over overskrifter å søke etter i filene

parsede_vedtak = main(directory_path, headings)
print(len(parsede_vedtak))
# Out:
# 13974

# %% [markdown]
# ### Resultat av parsingen
# Vi printer ut et vedtak for å se hvordan parsingen ser ut.

# %%
import pprint
pp = pprint.PrettyPrinter(indent=0, width=100)
pp.pprint(parsede_vedtak[100])
# Out:
# {'Dato': '04.11.2013\n\n',
# 'Klager har i det vesentlige anført': '',
# 'Nemnd': 'Fly',
# 'Nemnda bemerker': '',
# 'Saksnummer': '297/13F\n'
#               '\n'
#               'Tjenesteyter\n'
#               'Norwegian Air Shuttle ASA\n'
#               '\n'
#               'Krav om erstatning grunnet nektet ombordstigning.\n'
#               '\n'
#               'Klager har i det vesentlige anført:\n'
#               '\n'
#               'Klager skulle reise fra Manchester til Stavanger den 1. april 2013 kl. 10:30 med '
#               'DY1327.\n'
#               '\n'
#               'Da klager ankom terminal 1, var den i ferd med å bli evakuert grunnet bombetrussel. '
#               'Klager\n'
#               "fikk flere sms'er fra Norwegian med beskjed om at ny informasjon skulle komme. "
#               'Siste sms\n'
#               'kom kl. 12:17 om at mer info ville komme kl. 14:00.\n'
#               '\n'
#               'Kl. 12:40 kom det melding over høyttaleranlegget om at alle passasjerer som skulle '
#               'fly med\n'
#               'Norwegian måtte gå til terminal 2.\n'
#               '\n'
#               'Kl. 13:10 kom det melding over høyttaleranlegget om at alle passasjerer som skulle '
#               'fly med\n'
#               'Norwegian måtte gå til terminal 1.\n'
#               '\n'
#               'Kl. 13:50 kom det beskjed over høyttaler anlegget om at de som skulle reise med '
#               'Norwegian\n'
#               'måtte skynde seg gjennom sikkerhetskontrollen.\n'
#               '\n'
#               'Da klager ankom gate kl. 14:10, var Norwegians fly tatt av.\n'
#               '\n'
#               'Klager fikk etter flere henvendelser booket om flyet sitt til neste ledige avgang '
#               'den 3. april.\n'
#               'Klager ankom Stavanger 67 timer forsinket.\n'
#               '\n'
#               'Klager krever erstatning for 2 dagers tapt arbeidsfortjeneste, det vises til '
#               'fremlagt bekreftelse\n'
#               'fra arbeidsgiver.\n'
#               '\n'
#               'Det vises for øvrig til klagers brev.\n'
#               '\n'
#               'Norwegian har i det vesentlige anført:\n'
#               '\n'
#               'DY1327 ble forsinket 2 t 15 min grunnet ekstraordinære omstendigheter på '
#               'Manchester\n'
#               'flyplass, bombetrussel. Den uforutsette hendelsen medførte evakuering av '
#               'terminalen.\n'
#               '\n'
#               'Ut ifra informasjonen Norwegian hadde fått fra flyplassmyndighetene, sendte '
#               'selskapet\n'
#               'en sms til passasjerene om at ny info ville komme kl. 14:00. I samme sms stod det '
#               'også at\n'
#               'alle passasjerer måtte sjekke inn og møte ved gate til normal tid, da Norwegian '
#               'ville prøve å\n'
#               'innhente forsinkelsen.\n'
#               '\n'
#               'Da flyet var klart for boarding, ble avgangen ropt opp flere ganger.\n'
#               '\n'
#               'De passasjerene som ikke rakk avgangen, og som kontaktet Norwegian med en gang, '
#               'ble\n'
#               'booket om via Oslo samme dag.\n'
#               '\n'
#               'I de tilfeller hvor en uregelmessighet er forårsaket av en ekstraordinær '
#               'omstendighet, er\n'
#               'flyselskapet unntatt fra forpliktelse til å utbetale kompensasjon. I henhold til '
#               'EU-forordning\n'
#               '261/2004 artikkel 5(3) skal et transporterende flyselskap ikke være pålagt å betale '
#               'erstatning\n'
#               'i samsvar med artikkel 7, dersom det kan godtgjøre at innstillingen skyldtes '
#               'ekstraordinære\n'
#               'omstendigheter som ikke kunne vært unngått selv om alle rimelige tiltak var '
#               'truffet.\n'
#               'Omstendigheter som er utenfor flyselskapets kontroll er hendelser som ikke er '
#               'forårsaket av\n'
#               'en handling eller unnlatelse av flyselskapet.\n'
#               '\n'
#               'I henhold til C-402/07 i EU domstolen, Sturgeon v Condor, er  flyselskapene unntatt '
#               'fra\n'
#               'videre kompensasjon hvis forsinkelsen er på under 3 timer, eller årsaken til '
#               'forsinkelsen er\n'
#               'ekstraordinære omstendigheter utenfor flyselskapets kontroll som forhindrer '
#               'flyvningen. En\n'
#               'omstendighet som er utenfor selskapets kontroll er hendelser som ikke er forårsaket '
#               'av en\n'
#               'handling eller unnlatelse av flyselskapet.\n'
#               '\n'
#               'På grunnlag av ovennevnte kan Norwegian dessverre ikke imøtekomme klagers krav.\n'
#               '\n'
#               'Nemnda bemerker:\n'
#               '\n'
#               'Nemnda legger på bakgrunn av de foreliggende opplysninger til grunn at avgangen '
#               'ble\n'
#               'forsinket som følge av en bombetrussel på flyplassen. Dette er et forhold utenfor '
#               'Norwegians\n'
#               'kontroll.\n'
#               '\n'
#               'Nemnda legger videre til grunn at terminalen ble åpnet igjen ca. kl. 12:00, og at '
#               'klagerne kl.\n'
#               '12:17 fikk sms fra Norwegian om at avgangen var forsinket og at ny informasjon var '
#               'ventet\n'
#               'ca. kl. 14. Det stod videre at passasjerene var nødt til å møte opp og sjekke inn '
#               'til normal tid.\n'
#               'Det er uklart for nemnda hva som menes med «normal tid» i og med at avgangen '
#               'allerede på\n'
#               'dette tidspunkt var forsinket med omlag 1 time og 45 minutter, og det ikke var '
#               'fastsatt noen\n'
#               'ny avgangstid.\n'
#               '\n'
#               'Norwegian opplyser at flyet ble forsinket med 2 timer og 15 minutter. Dette skulle '
#               'i så fall\n'
#               'tilsi at flyet tok av klokken 12.45. Dette passer imidlertid ikke med den '
#               'informasjon klager\n'
#               'opplyser ble gitt over høyttaleren.\n'
#               '\n'
#               'Nemnda finner det etter en samlet vurdering mest sannsynlig at Norwegian ikke kan '
#               'lastes\n'
#               'for at klager ikke kom med flyet. Det er sannsynlig at det var et stort antall fly '
#               'som var blitt\n'
#               'forsinket, og Norwegian var i likhet med andre selskap avhengig av tildelingen av '
#               'nye tider for\n'
#               'avgang samt omfordeling av utganger mv. De enkelte selskap måtte forholde seg til '
#               'dette og\n'
#               'kunne ikke vente for å få med alle passasjerene.\n'
#               '\n'
#               'Klager forlot flyplassen kl. 16.00 uten å ha blitt omrutet til annen flygning. Han '
#               'gikk således\n'
#               'glipp av Norwegians omruting via Oslo samme dag. Etter nemndas vurdering må klager '
#               'selv\n'
#               'bære ansvaret for de konsekvenser det medførte.\n'
#               '\n'
#               'Nemnda finner etter dette ikke å kunne anbefale at klager gis medhold.\n'
#               '\n'
#               'Vedtak:\n'
#               '\n'
#               'Transportklagenemnda-fly finner ikke å kunne anbefale at klager gis medhold.\n'
#               '\n'
#               'Vedtaket var enstemmig.\n',
# 'Sammendrag': '\nKrav om erstatning grunnet nektet ombordstigning.\n\n',
# 'Tjenesteyter_avviser': '',
# 'Tjenesteyter_avviser_bool': False,
# 'Tjenesteytere': '',
# 'Tjenesteyterne har i det vesentlige anført': '',
# 'Vedtak': '',
# 'Vedtak_komplett': 'Vedtak i Transportklagenemnda - Fly\n'
#                    '\n'
#                    'Sammendrag\n'
#                    '\n'
#                    'Krav om erstatning grunnet nektet ombordstigning.\n'
#                    '\n'
#                    'Dato\n'
#                    '04.11.2013\n'
#                    '\n'
#                    'Saksnummer\n'
#                    '297/13F\n'
#                    '\n'
#                    'Tjenesteyter\n'
#                    'Norwegian Air Shuttle ASA\n'
#                    '\n'
#                    'Krav om erstatning grunnet nektet ombordstigning.\n'
#                    '\n'
#                    'Klager har i det vesentlige anført:\n'
#                    '\n'
#                    'Klager skulle reise fra Manchester til Stavanger den 1. april 2013 kl. 10:30 '
#                    'med DY1327.\n'
#                    '\n'
#                    'Da klager ankom terminal 1, var den i ferd med å bli evakuert grunnet '
#                    'bombetrussel. Klager\n'
#                    "fikk flere sms'er fra Norwegian med beskjed om at ny informasjon skulle komme. "
#                    'Siste sms\n'
#                    'kom kl. 12:17 om at mer info ville komme kl. 14:00.\n'
#                    '\n'
#                    'Kl. 12:40 kom det melding over høyttaleranlegget om at alle passasjerer som '
#                    'skulle fly med\n'
#                    'Norwegian måtte gå til terminal 2.\n'
#                    '\n'
#                    'Kl. 13:10 kom det melding over høyttaleranlegget om at alle passasjerer som '
#                    'skulle fly med\n'
#                    'Norwegian måtte gå til terminal 1.\n'
#                    '\n'
#                    'Kl. 13:50 kom det beskjed over høyttaler anlegget om at de som skulle reise '
#                    'med Norwegian\n'
#                    'måtte skynde seg gjennom sikkerhetskontrollen.\n'
#                    '\n'
#                    'Da klager ankom gate kl. 14:10, var Norwegians fly tatt av.\n'
#                    '\n'
#                    'Klager fikk etter flere henvendelser booket om flyet sitt til neste ledige '
#                    'avgang den 3. april.\n'
#                    'Klager ankom Stavanger 67 timer forsinket.\n'
#                    '\n'
#                    'Klager krever erstatning for 2 dagers tapt arbeidsfortjeneste, det vises til '
#                    'fremlagt bekreftelse\n'
#                    'fra arbeidsgiver.\n'
#                    '\n'
#                    'Det vises for øvrig til klagers brev.\n'
#                    '\n'
#                    'Norwegian har i det vesentlige anført:\n'
#                    '\n'
#                    'DY1327 ble forsinket 2 t 15 min grunnet ekstraordinære omstendigheter på '
#                    'Manchester\n'
#                    'flyplass, bombetrussel. Den uforutsette hendelsen medførte evakuering av '
#                    'terminalen.\n'
#                    '\n'
#                    'Ut ifra informasjonen Norwegian hadde fått fra flyplassmyndighetene, sendte '
#                    'selskapet\n'
#                    'en sms til passasjerene om at ny info ville komme kl. 14:00. I samme sms stod '
#                    'det også at\n'
#                    'alle passasjerer måtte sjekke inn og møte ved gate til normal tid, da '
#                    'Norwegian ville prøve å\n'
#                    'innhente forsinkelsen.\n'
#                    '\n'
#                    'Da flyet var klart for boarding, ble avgangen ropt opp flere ganger.\n'
#                    '\n'
#                    'De passasjerene som ikke rakk avgangen, og som kontaktet Norwegian med en '
#                    'gang, ble\n'
#                    'booket om via Oslo samme dag.\n'
#                    '\n'
#                    'I de tilfeller hvor en uregelmessighet er forårsaket av en ekstraordinær '
#                    'omstendighet, er\n'
#                    'flyselskapet unntatt fra forpliktelse til å utbetale kompensasjon. I henhold '
#                    'til EU-forordning\n'
#                    '261/2004 artikkel 5(3) skal et transporterende flyselskap ikke være pålagt å '
#                    'betale erstatning\n'
#                    'i samsvar med artikkel 7, dersom det kan godtgjøre at innstillingen skyldtes '
#                    'ekstraordinære\n'
#                    'omstendigheter som ikke kunne vært unngått selv om alle rimelige tiltak var '
#                    'truffet.\n'
#                    'Omstendigheter som er utenfor flyselskapets kontroll er hendelser som ikke er '
#                    'forårsaket av\n'
#                    'en handling eller unnlatelse av flyselskapet.\n'
#                    '\n'
#                    'I henhold til C-402/07 i EU domstolen, Sturgeon v Condor, er  flyselskapene '
#                    'unntatt fra\n'
#                    'videre kompensasjon hvis forsinkelsen er på under 3 timer, eller årsaken til '
#                    'forsinkelsen er\n'
#                    'ekstraordinære omstendigheter utenfor flyselskapets kontroll som forhindrer '
#                    'flyvningen. En\n'
#                    'omstendighet som er utenfor selskapets kontroll er hendelser som ikke er '
#                    'forårsaket av en\n'
#                    'handling eller unnlatelse av flyselskapet.\n'
#                    '\n'
#                    'På grunnlag av ovennevnte kan Norwegian dessverre ikke imøtekomme klagers '
#                    'krav.\n'
#                    '\n'
#                    'Nemnda bemerker:\n'
#                    '\n'
#                    'Nemnda legger på bakgrunn av de foreliggende opplysninger til grunn at '
#                    'avgangen ble\n'
#                    'forsinket som følge av en bombetrussel på flyplassen. Dette er et forhold '
#                    'utenfor Norwegians\n'
#                    'kontroll.\n'
#                    '\n'
#                    'Nemnda legger videre til grunn at terminalen ble åpnet igjen ca. kl. 12:00, og '
#                    'at klagerne kl.\n'
#                    '12:17 fikk sms fra Norwegian om at avgangen var forsinket og at ny informasjon '
#                    'var ventet\n'
#                    'ca. kl. 14. Det stod videre at passasjerene var nødt til å møte opp og sjekke '
#                    'inn til normal tid.\n'
#                    'Det er uklart for nemnda hva som menes med «normal tid» i og med at avgangen '
#                    'allerede på\n'
#                    'dette tidspunkt var forsinket med omlag 1 time og 45 minutter, og det ikke var '
#                    'fastsatt noen\n'
#                    'ny avgangstid.\n'
#                    '\n'
#                    'Norwegian opplyser at flyet ble forsinket med 2 timer og 15 minutter. Dette '
#                    'skulle i så fall\n'
#                    'tilsi at flyet tok av klokken 12.45. Dette passer imidlertid ikke med den '
#                    'informasjon klager\n'
#                    'opplyser ble gitt over høyttaleren.\n'
#                    '\n'
#                    'Nemnda finner det etter en samlet vurdering mest sannsynlig at Norwegian ikke '
#                    'kan lastes\n'
#                    'for at klager ikke kom med flyet. Det er sannsynlig at det var et stort antall '
#                    'fly som var blitt\n'
#                    'forsinket, og Norwegian var i likhet med andre selskap avhengig av tildelingen '
#                    'av nye tider for\n'
#                    'avgang samt omfordeling av utganger mv. De enkelte selskap måtte forholde seg '
#                    'til dette og\n'
#                    'kunne ikke vente for å få med alle passasjerene.\n'
#                    '\n'
#                    'Klager forlot flyplassen kl. 16.00 uten å ha blitt omrutet til annen flygning. '
#                    'Han gikk således\n'
#                    'glipp av Norwegians omruting via Oslo samme dag. Etter nemndas vurdering må '
#                    'klager selv\n'
#                    'bære ansvaret for de konsekvenser det medførte.\n'
#                    '\n'
#                    'Nemnda finner etter dette ikke å kunne anbefale at klager gis medhold.\n'
#                    '\n'
#                    'Vedtak:\n'
#                    '\n'
#                    'Transportklagenemnda-fly finner ikke å kunne anbefale at klager gis medhold.\n'
#                    '\n'
#                    'Vedtaket var enstemmig.'}

# %% [markdown]
# ### Videre bearbeiding
#
# Vi ser at tekstfeltene kan forbedres på to punkter:
# 1. De har noen innledende og avsluttende linjeskift (\n). De skal ikke være med.
# 2. Teksten har også noen uønskede linjeskift i teksten.  Dette er linjeskift som stammer fra layouten i pdf-filene. De ønsker vi også å fjerne.

# %%
# Funksjon for å behandle tekstverdier i hvert vedtak
def behandle_tekstverdier_i_vedtak(parsede_vedtak):
    # Itererer gjennom hvert vedtak (ordbok) i listen
    for vedtak in parsede_vedtak:
        # Itererer gjennom hvert nøkkel-verdi-par i vedtaket
        for key, value in vedtak.items():
            # 1. Sjekker om verdien er en tekststreng
            if isinstance(value, str):
                # 2. Fjerner ledende og etterfølgende mellomrom
                renset_tekst = value.strip()

                # 3. Splitter teksten i verdifeltet til avsnitt (\n\n)
                avsnitt = renset_tekst.split('\n\n')
                # 4. For hvert avsnitt, erstatter \n med mellomrom
                behandlet_avsnitt = [text.replace('\n', ' ') for text in avsnitt]
               
                # Setter sammen avsnittene igjen med \n\n som skilletegn
                sammensatt_tekst = '\n\n'.join(behandlet_avsnitt)

                # Oppdaterer verdien i vedtaket med den sammensatte teksten
                vedtak[key] = sammensatt_tekst

    return parsede_vedtak  # Returnerer listen med vedtak etter at tekstverdiene er behandlet


# Kaller funksjonen med listen over parsede vedtak
#print(parsede_vedtak)  # Print to check if the list is empty or not
behandlede_vedtak = behandle_tekstverdier_i_vedtak(parsede_vedtak)



# Skriver ut de behandlete vedtakene for verifisering
#for vedtak in behandlede_vedtak:
   # print(vedtak)

# %%
import pprint
pp = pprint.PrettyPrinter(indent=0, width=100)
pp.pprint(behandlede_vedtak[2])
# Out:
# {'Dato': '02.10.2015',
# 'Klager har i det vesentlige anført': '',
# 'Nemnd': 'Fly',
# 'Nemnda bemerker': '',
# 'Saksnummer': '0027/15F\n'
#               '\n'
#               'Tjenesteyter Supersaver\n'
#               '\n'
#               'Klager har i det vesentlige anført:\n'
#               '\n'
#               'Klager hadde bestilt en reise hos Supersaver. I ettertid ville han endre navn på '
#               'bestillingen og kontaktet reisebyrået. De henviste ham til Qatar. Klager kontaktet '
#               'Qatar, som sa at han skulle ordne dette og sende mail til Supersaver. Klager '
#               'informerte Supersaver om dette.\n'
#               '\n'
#               'En ukes tid senere ringte Supersaver og sa at klager måtte betale et gebyr på '
#               'kroner 1 095 for endringen, og at de ville sende en bekreftelse og ny billett.\n'
#               '\n'
#               'Klager ventet en uke uten å få bekreftelse fra Supersaver på navneendringen. Han '
#               'forsøkte å kontakte reisebyrået uten å komme gjennom på telefon. Han ringte derfor '
#               'Qatar Airways, og det endte med at flyselskapet måtte sende han en bekreftelse på '
#               'navneendringen.\n'
#               '\n'
#               'Klager stiller seg kritisk til at Supersaver har tatt betalt for en tjeneste de '
#               'ikke har utført.\n'
#               '\n'
#               'Klager krever refusjon av endringsgebyr, kroner 1 095.\n'
#               '\n'
#               'Det vises for øvrig til klagers brev.\n'
#               '\n'
#               'Supersaver har i det vesentlige anført:\n'
#               '\n'
#               'Supersaver har hjulpet klager med en navneendring. Dette koster kroner 595 fra '
#               'Supersaver og kroner 500 fra flyselskapet. For å få gjennomført en navnendring må '
#               'Supersaver få dette godkjent av flyselskapet.\n'
#               '\n'
#               'I dette tilfellet er det Supersaver, ikke Qatar Airways, som har utført '
#               'navneendringen. Dessverre ble det ikke sendt en bekreftelse til klager på '
#               'navneendringen, men dette kvalifiserer ikke til refusjon av endringsgebyret. '
#               'Navneendringen ble gjennomført og klager kunne reise på billetten uten noe '
#               'problem.\n'
#               '\n'
#               'Supersaver kan ikke imøtekomme klagers krav.\n'
#               '\n'
#               'Nemnda bemerker:\n'
#               '\n'
#               'Klager bestilte billetter gjennom et reisebyrå, Supersaver. Kommunikasjon mellom '
#               'klager og flyselskapet går da som hovedregel gjennom Supersaver.\n'
#               '\n'
#               'Klager har anført at han ble henvist videre til Qatar da han tok opp navneendringen '
#               'med Supersaver. Han anfører videre at Qatar sa de skulle ordne dette og sende mail '
#               'til Supersaver om at alt var i orden. Supersaver anfører at det er de som har '
#               'foretatt endringen. De glemte imidlertid å sende bekreftelse til klager. Klager har '
#               'opplyst at han mottok bekreftelsen fra Qatar.\n'
#               '\n'
#               'Nemnda finner saken uklar. Supersaver må ta på seg en del av ansvaret for dette ved '
#               'at de ikke sendte bekreftelse til klager om endringen. Det skaper usikkerhet om '
#               'endringen er foretatt av Supersaver eller Qatar. Uansett har ikke Supersaver utført '
#               'sin jobb på en tilfredsstillende måte. Nemnda anbefaler etter omstendighetene at '
#               'Supersaver refunderer sitt gebyr, dvs NOK 595.\n'
#               '\n'
#               'Vedtak:\n'
#               '\n'
#               'Transportklagenemnda-fly anbefaler at Supersaver refunderer NOK 595.\n'
#               '\n'
#               'Vedtaket var enstemmig.',
# 'Sammendrag': 'Krav om refusjon av gebyr for navneendring.',
# 'Tjenesteyter_avviser': '',
# 'Tjenesteyter_avviser_bool': False,
# 'Tjenesteytere': '',
# 'Tjenesteyterne har i det vesentlige anført': '',
# 'Vedtak': '',
# 'Vedtak_komplett': 'Vedtak i Transportklagenemnda - Fly\n'
#                    '\n'
#                    'Sammendrag\n'
#                    '\n'
#                    'Krav om refusjon av gebyr for navneendring.\n'
#                    '\n'
#                    'Dato 02.10.2015\n'
#                    '\n'
#                    'Saksnummer 0027/15F\n'
#                    '\n'
#                    'Tjenesteyter Supersaver\n'
#                    '\n'
#                    'Klager har i det vesentlige anført:\n'
#                    '\n'
#                    'Klager hadde bestilt en reise hos Supersaver. I ettertid ville han endre navn '
#                    'på bestillingen og kontaktet reisebyrået. De henviste ham til Qatar. Klager '
#                    'kontaktet Qatar, som sa at han skulle ordne dette og sende mail til '
#                    'Supersaver. Klager informerte Supersaver om dette.\n'
#                    '\n'
#                    'En ukes tid senere ringte Supersaver og sa at klager måtte betale et gebyr på '
#                    'kroner 1 095 for endringen, og at de ville sende en bekreftelse og ny '
#                    'billett.\n'
#                    '\n'
#                    'Klager ventet en uke uten å få bekreftelse fra Supersaver på navneendringen. '
#                    'Han forsøkte å kontakte reisebyrået uten å komme gjennom på telefon. Han '
#                    'ringte derfor Qatar Airways, og det endte med at flyselskapet måtte sende han '
#                    'en bekreftelse på navneendringen.\n'
#                    '\n'
#                    'Klager stiller seg kritisk til at Supersaver har tatt betalt for en tjeneste '
#                    'de ikke har utført.\n'
#                    '\n'
#                    'Klager krever refusjon av endringsgebyr, kroner 1 095.\n'
#                    '\n'
#                    'Det vises for øvrig til klagers brev.\n'
#                    '\n'
#                    'Supersaver har i det vesentlige anført:\n'
#                    '\n'
#                    'Supersaver har hjulpet klager med en navneendring. Dette koster kroner 595 fra '
#                    'Supersaver og kroner 500 fra flyselskapet. For å få gjennomført en navnendring '
#                    'må Supersaver få dette godkjent av flyselskapet.\n'
#                    '\n'
#                    'I dette tilfellet er det Supersaver, ikke Qatar Airways, som har utført '
#                    'navneendringen. Dessverre ble det ikke sendt en bekreftelse til klager på '
#                    'navneendringen, men dette kvalifiserer ikke til refusjon av endringsgebyret. '
#                    'Navneendringen ble gjennomført og klager kunne reise på billetten uten noe '
#                    'problem.\n'
#                    '\n'
#                    'Supersaver kan ikke imøtekomme klagers krav.\n'
#                    '\n'
#                    'Nemnda bemerker:\n'
#                    '\n'
#                    'Klager bestilte billetter gjennom et reisebyrå, Supersaver. Kommunikasjon '
#                    'mellom klager og flyselskapet går da som hovedregel gjennom Supersaver.\n'
#                    '\n'
#                    'Klager har anført at han ble henvist videre til Qatar da han tok opp '
#                    'navneendringen med Supersaver. Han anfører videre at Qatar sa de skulle ordne '
#                    'dette og sende mail til Supersaver om at alt var i orden. Supersaver anfører '
#                    'at det er de som har foretatt endringen. De glemte imidlertid å sende '
#                    'bekreftelse til klager. Klager har opplyst at han mottok bekreftelsen fra '
#                    'Qatar.\n'
#                    '\n'
#                    'Nemnda finner saken uklar. Supersaver må ta på seg en del av ansvaret for '
#                    'dette ved at de ikke sendte bekreftelse til klager om endringen. Det skaper '
#                    'usikkerhet om endringen er foretatt av Supersaver eller Qatar. Uansett har '
#                    'ikke Supersaver utført sin jobb på en tilfredsstillende måte. Nemnda anbefaler '
#                    'etter omstendighetene at Supersaver refunderer sitt gebyr, dvs NOK 595.\n'
#                    '\n'
#                    'Vedtak:\n'
#                    '\n'
#                    'Transportklagenemnda-fly anbefaler at Supersaver refunderer NOK 595.\n'
#                    '\n'
#                    'Vedtaket var enstemmig.'}

# %% [markdown]
# ## Flertall og mindretall
#
# - Sjekke for mindretall og lagre i boolsk variabel.
# - Kjøre statistikk som kontrollerer søkekriteriene for mindretall og flertall

# %%
# Uttrykk å søke etter, enkelt å endre ved å bare oppdatere denne listen
expressions = ["flertall", "flertallet", "mindretall", "mindretallet",
              "Flertall", "Flertallet", "Mindretall", "Mindretallet"]

# Funksjon for å sjekke tekst for noen av de gitte uttrykkene og oppdatere ordboken
def check_text_and_update_dictionary(dictionary, expressions):
    # Sjekker om 'dictionary' faktisk er en ordbok
    if not isinstance(dictionary, dict):
        raise ValueError("Funksjonen forventer en ordbok som input.")

    # Henter teksten som skal søkes i
    text_to_search = dictionary.get("Nemnda bemerker", "")
    
    # Søker etter noen av uttrykkene i teksten
    found_expression = any(expression in text_to_search for expression in expressions)

    # Oppdaterer ordboken basert på om et uttrykk ble funnet
    dictionary["Har_mindretall"] = "True" if found_expression else "False"

# Kaller funksjonen for hver ordbok i listen
for vedtak in behandlede_vedtak:
    check_text_and_update_dictionary(vedtak, expressions)

# Skriver ut den oppdaterte listen med ordbøker
print(behandlede_vedtak[0])
# Out:
# {'Sammendrag': 'Krav om standarderstatning og refusjon ved forsinkelse.', 'Dato': '20.06.2017', 'Saksnummer': '2016-00844', 'Tjenesteytere': 'Norwegian', 'Klager har i det vesentlige anført': 'Klager skulle reise med Norwegians flyvning DY7106 fra Las Vegas (LAS) til København (CPH) 16. juli 2016 kl. 18.30 lokal tid. Flyvningen ble forsinket, og klager mistet sin forbindelse fra København til Bergen med SAS. \n\nVarmt vær i Las Vegas i juli måned kan etter klagers syn ikke anses som en ekstraordinær omstendighet. \n\nKlager har på ovennevnte bakgrunn fremsatt krav om standarderstatning i henhold til EU-forordning 261/2004 på 600 euro, samt refusjon av kroner 2 067 for kjøp av nye flybilletter fra København til Bergen.', 'Tjenesteyterne har i det vesentlige anført': 'Norwegians flyvning DY7106 fra Las Vegas til København 16. juli 2016 ble forsinket med fem timer og 42 minutter. Årsaken til forsinkelsen var værforholdene i Las Vegas denne dagen. Det var svært høye temperaturer som forårsaket forsinkelsen. \n\nPå Norwegians langdistanseruter benyttes en svært stor og tung flymaskin som skal kunne fly store distanser. Maskinen kunne ikke ta av som følge av en kombinasjon av høy temperatur og flyets vekt. Det eneste alternativet ville vært å ta av med mindre drivstoff enn nødvendig for å redusere vekten, noe som ville nødvendiggjort en mellomlanding for å fylle drivstoff. Et slikt tiltak er svært risikabelt, samt at det vil være vanskelig å planlegge ventetid på andre flyplasser. Denne muligheten ville mest sannsynlig ha forårsaket en enda lengre forsinkelse for passasjerene. \n\nOmruting med andre flyselskap ville ikke være hensiktsmessig i dette tilfellet, da det kun var mindre maskiner som tok av fra Las Vegas denne ettermiddagen, slik at passasjerene i så måte hadde vært nødt til å mellomlande flere ganger før de ville ankommet København. \n\nUregelmessigheten utgjør i dette tilfellet en ekstraordinær omstendighet og en hendelse utenfor flyselskapets kontroll. Norwegian har følgelig ingen plikt til å utbetale standarderstatning i henhold til EU-forordning 261/2004 eller erstatning eller refusjon på annet grunnlag. Norwegian avviser på ovennevnte bakgrunn klagers fremsatte krav i saken.', 'Nemnda bemerker': 'DY7106 fra Las Vegas til København 16. juli 2016 ble forsinket med fem timer og 42 minutter. \n\nForsinkelse som medfører at passasjerene kommer frem til det endelige bestemmelsesstedet tre timer eller mer etter det planlagte ankomsttidspunktet gir rett til erstatning, med mindre flyselskapet godtgjør at forsinkelsen skyldes ekstraordinære omstendigheter som ikke kunne vært unngått selv om alle rimelige tiltak var truffet. Det vises til EU-forordning 261/2004 artikkel 6 jf. artikkel 7, jf. artikkel 5 nr. 3, jf. EU- domstolens avgjørelser i Sturgeon m.fl. mot Condor (C-402/07) og Nelson m.fl. mot Lufthansa (C-581/10 og C-629/10).\n\nVærforhold som påvirker flytrafikken ved at det ikke er mulig å lande/ta av, kan være en slik ekstraordinær omstendighet som medfører at den reisende ikke har krav på erstatning. Dette må vurderes konkret. \n\nI dette tilfellet er det opplyst at forsinkelsen skyldtes høy varme. Det aktuelle flyet var svært stort og tungt, slik at flyet ikke kunne lette med så mye drivstoff. Dersom flyet skulle tatt av med mindre drivstoff, ville det være nødvendig å mellomlande. Det ble vurdert at en mellomlanding ikke var aktuelt, da det trolig ville medføre ytterligere forsinkelser.\n\nI henhold til vedlagte rapporter fremgår det at temperaturen var rundt 41 grader celsius den aktuelle dagen. Nemnda har vanskelig for å se at dette er å anse som så høy varme at det må vurderes som en ekstraordinær omstendighet. 41 grader midt på sommeren i Las Vegas må etter nemndas syn være noe flyselskapene må regne med. Nemnda betviler ikke opplysningene om at det aktuelle flyet ikke kunne lette den dagen. Etter nemndas syn er dette imidlertid noe flyselskapene kan ta høyde for, ved for eksempel å planlegge mellomlandinger i s ...

# %% [markdown]
# ## Lagrer vedtakene til fil. Bruker JSON

# %%
import json

filename = 'vedtak.json'

with open(filename, 'w', encoding='utf-8') as f:
    json.dump(behandlede_vedtak, f, indent=4, ensure_ascii=False)
